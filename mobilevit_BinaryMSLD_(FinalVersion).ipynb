# %% [markdown]
# # First we start by downloading all necessary libraries/classes

# %%
# !pip install torchinfo
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %%
import matplotlib.pyplot as plt
import zipfile
import torch
import torchvision
from torch import nn
from torchvision import transforms
from torchinfo import summary
import os
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from tqdm.auto import tqdm
from typing import Dict, List, Tuple
from PIL import Image
import requests
import timm
from timm.data import create_transform

# %%
def set_seeds(seed: int=42):
    # Set the seed for general torch operations
    torch.manual_seed(seed)
    # Set the seed for CUDA torch operations (ones that happen on the GPU)
    torch.cuda.manual_seed(seed)

# %% [markdown]
# # this code is to check if our code is running on the GPU correctly

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %% [markdown]
# # Setting up the pretrained weights, defining our classes, and adding a trainable layer

# %%
# Load pretrained  model
pretrained_mobilevit = timm.create_model("mobilevit_s.cvnets_in1k", pretrained=True).to(device)

# Freeze model parameters
for parameter in pretrained_mobilevit.parameters():
    parameter.requires_grad = False

for name, param in list(pretrained_mobilevit.named_parameters())[-10:]:
    param.requires_grad = True
# Define class names
class_names = ['Monkeypox', 'Others']

# Set random seeds (assuming set_seeds is defined)
set_seeds()

# Replace classification head

pretrained_mobilevit.head = nn.Sequential(
    nn.AdaptiveAvgPool2d(1),# Pool to (batch_size, 640, 1, 1)
    nn.Flatten(),
    nn.Linear(640, 256),
    nn.ReLU(),
    nn.Dropout(p=0.3),
    nn.Linear(256, 2)
).to(device)




# Get pretrained config
pretrained_cfg = pretrained_mobilevit.pretrained_cfg

# Extract transform parameters safely
input_size = pretrained_cfg.input_size if hasattr(pretrained_cfg, "input_size") else 256
mean = pretrained_cfg.mean if hasattr(pretrained_cfg, "mean") else (0.5, 0.5, 0.5)
std = pretrained_cfg.std if hasattr(pretrained_cfg, "std") else (0.5, 0.5, 0.5)
interpolation = pretrained_cfg.interpolation if hasattr(pretrained_cfg, "interpolation") else "bilinear"

# Define transforms using timm's recommended settings
pretrained_mobilevit_transforms = create_transform(
    input_size=input_size,
    mean=mean,
    std=std,
    interpolation=interpolation
)

# Print model architecture
#print(pretrained_mobilevit)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/22.4M [00:00<?, ?B/s]

# %% [markdown]
# # Here is the model's architecture:

# %%
# Print a summary using torchinfo (uncomment for actual output)
summary(model= pretrained_mobilevit ,
        input_size=(16, 3, 256, 256), # (batch_size, color_channels, height, width)
         #col_names=["input_size"], # uncomment for smaller output
         col_names=["input_size", "output_size", "num_params", "trainable"],
        col_width=20,
        row_settings=["var_names"]
)
# Out:
# =======================================================================================================================================
# Layer (type (var_name))                                 Input Shape          Output Shape         Param #              Trainable
# =======================================================================================================================================
# ByobNet (ByobNet)                                       [16, 3, 256, 256]    [16, 2]              --                   Partial
# ├─ConvNormAct (stem)                                    [16, 3, 256, 256]    [16, 16, 128, 128]   --                   False
# │    └─Conv2d (conv)                                    [16, 3, 256, 256]    [16, 16, 128, 128]   (432)                False
# │    └─BatchNormAct2d (bn)                              [16, 16, 128, 128]   [16, 16, 128, 128]   32                   False
# │    │    └─Identity (drop)                             [16, 16, 128, 128]   [16, 16, 128, 128]   --                   --
# │    │    └─SiLU (act)                                  [16, 16, 128, 128]   [16, 16, 128, 128]   --                   --
# ├─Sequential (stages)                                   [16, 16, 128, 128]   [16, 160, 8, 8]      --                   Partial
# │    └─Sequential (0)                                   [16, 16, 128, 128]   [16, 32, 128, 128]   --                   False
# │    │    └─BottleneckBlock (0)                         [16, 16, 128, 128]   [16, 32, 128, 128]   (3,968)              False
# │    └─Sequential (1)                                   [16, 32, 128, 128]   [16, 64, 64, 64]     --                   False
# │    │    └─BottleneckBlock (0)                         [16, 32, 128, 128]   [16, 64, 64, 64]     (14,080)             False
# │    │    └─BottleneckBlock (1)                         [16, 64, 64, 64]     [16, 64, 64, 64]     (36,224)             False
# │    │    └─BottleneckBlock (2)                         [16, 64, 64, 64]     [16, 64, 64, 64]     (36,224)             False
# │    └─Sequential (2)                                   [16, 64, 64, 64]     [16, 96, 32, 32]     --                   False
# │    │    └─BottleneckBlock (0)                         [16, 64, 64, 64]     [16, 96, 32, 32]     (44,480)             False
# │    │    └─MobileVitBlock (1)                          [16, 96, 32, 32]     [16, 96, 32, 32]     (612,288)            False
# │    └─Sequential (3)                                   [16, 96, 32, 32]     [16, 128, 16, 16]    --                   False
# │    │    └─BottleneckBlock (0)                         [16, 96, 32, 32]     [16, 128, 16, 16]    (91,264)             False
# │    │    └─MobileVitBlock (1)                          [16, 128, 16, 16]    [16, 128, 16, 16]    (1,680,768)          False
# │    └─Sequential (4)                                   [16, 128, 16, 16]    [16, 160, 8, 8]      --                   Partial
# │    │    └─BottleneckBlock (0)                         [16, 128, 16, 16]    [16, 160, 8, 8]      (154,432)            False
# │    │    └─MobileVitBlock (1)                          [16, 160, 8, 8]      [16, 160, 8, 8]      2,159,760            Partial
# ├─ConvNormAct (final_conv)                              [16, 160, 8, 8]      [16, 640, 8, 8]      --                   True
# │    └─Conv2d (conv)                                    [16, 160, 8, 8]      [16, 640, 8, 8]      102,400              True
# │    └─BatchNormAct2d (bn)                              [16, 640, 8, 8]      [16, 640, 8, 8]      1,280                True
# │    │    └─Identity (drop)                             [16, 640, 8, 8]      [16, 640, 8, 8]      --                   --
# │    │    └─SiLU (act)                                  [16, 640, 8, 8]      [16, 640, 8, 8]      --                   --
# ├─Sequential (head)                                     [16, 640, 8, 8]      [16, 2]              --                   True
# │    └─AdaptiveAvgPool2d (0)                            [16, 640, 8, 8]      [16, 640, 1, 1]      --                   --
# │    └─Flatten (1)                                      [16, 640, 1, 1]      [16, 640]            --                   --
# │    └─Linear (2)                                       [16, 640]            [16, 256]            164,096              True
# │    └─ReLU (3)                                         [16, 256]            [16, 256]            --                   --
# │    └─Dropout (4)                                      [16, 256]            [16, 256]            --                   --
# │    └─Linear (5)                                       [16, 256]            [16, 2]              514                  True
# =======================================================================================================================================
# Total params: 5,102,242
# Trainable params: 729,730
# Non-trainable params: 4,372,512
# Total mult-adds (Units.GIGABYTES): 17.67
# =======================================================================================================================================
# Input size (MB): 12.58
# Forward/backward pass size (MB): 2345.04
# Params size (MB): 20.36
# Estimated Total Size (MB): 2377.99
# =======================================================================================================================================

# %%
model = pretrained_mobilevit  # Make sure the model is assigned to a variable

# %%
for name, param in model.named_parameters():
    print(f"{name}: {'Trainable' if param.requires_grad else 'Frozen'}")
# Out:
# stem.conv.weight: Frozen
# stem.bn.weight: Frozen
# stem.bn.bias: Frozen
# stages.0.0.conv1_1x1.conv.weight: Frozen
# stages.0.0.conv1_1x1.bn.weight: Frozen
# stages.0.0.conv1_1x1.bn.bias: Frozen
# stages.0.0.conv2_kxk.conv.weight: Frozen
# stages.0.0.conv2_kxk.bn.weight: Frozen
# stages.0.0.conv2_kxk.bn.bias: Frozen
# stages.0.0.conv3_1x1.conv.weight: Frozen
# stages.0.0.conv3_1x1.bn.weight: Frozen
# stages.0.0.conv3_1x1.bn.bias: Frozen
# stages.1.0.conv1_1x1.conv.weight: Frozen
# stages.1.0.conv1_1x1.bn.weight: Frozen
# stages.1.0.conv1_1x1.bn.bias: Frozen
# stages.1.0.conv2_kxk.conv.weight: Frozen
# stages.1.0.conv2_kxk.bn.weight: Frozen
# stages.1.0.conv2_kxk.bn.bias: Frozen
# stages.1.0.conv3_1x1.conv.weight: Frozen
# stages.1.0.conv3_1x1.bn.weight: Frozen
# stages.1.0.conv3_1x1.bn.bias: Frozen
# stages.1.1.conv1_1x1.conv.weight: Frozen
# stages.1.1.conv1_1x1.bn.weight: Frozen
# stages.1.1.conv1_1x1.bn.bias: Frozen
# stages.1.1.conv2_kxk.conv.weight: Frozen
# stages.1.1.conv2_kxk.bn.weight: Frozen
# stages.1.1.conv2_kxk.bn.bias: Frozen
# stages.1.1.conv3_1x1.conv.weight: Frozen
# stages.1.1.conv3_1x1.bn.weight: Frozen
# stages.1.1.conv3_1x1.bn.bias: Frozen
# stages.1.2.conv1_1x1.conv.weight: Frozen
# stages.1.2.conv1_1x1.bn.weight: Frozen
# stages.1.2.conv1_1x1.bn.bias: Frozen
# stages.1.2.conv2_kxk.conv.weight: Frozen
# stages.1.2.conv2_kxk.bn.weight: Frozen
# stages.1.2.conv2_kxk.bn.bias: Frozen
# stages.1.2.conv3_1x1.conv.weight: Frozen
# stages.1.2.conv3_1x1.bn.weight: Frozen
# stages.1.2.conv3_1x1.bn.bias: Frozen
# stages.2.0.conv1_1x1.conv.weight: Frozen
# stages.2.0.conv1_1x1.bn.weight: Frozen
# stages.2.0.conv1_1x1.bn.bias: Frozen
# stages.2.0.conv2_kxk.conv.weight: Frozen
# stages.2.0.conv2_kxk.bn.weight: Frozen
# stages.2.0.conv2_kxk.bn.bias: Frozen
# stages.2.0.conv3_1x1.conv.weight: Frozen
# stages.2.0.conv3_1x1.bn.weight: Frozen
# stages.2.0.conv3_1x1.bn.bias: Frozen
# stages.2.1.conv_kxk.conv.weight: Frozen
# stages.2.1.conv_kxk.bn.weight: Frozen
# stages.2.1.conv_kxk.bn.bias: Frozen
# stages.2.1.conv_1x1.weight: Frozen
# stages.2.1.transformer.0.norm1.weight: Frozen
# stages.2.1.transformer.0.norm1.bias: Frozen
# stages.2.1.transformer.0.attn.qkv.weight: Frozen
# stages.2.1.transformer.0.attn.qkv.bias: Frozen
# stages.2.1.transformer.0.attn.proj.weight: Frozen
# stages.2.1.transformer.0.attn.proj.bias: Frozen
# stages.2.1.transformer.0.norm2.weight: Frozen
# stages.2.1.transformer.0.norm2.bias: Frozen
# stages.2.1.transformer.0.mlp.fc1.weight: Frozen
# stages.2.1.transformer.0.mlp.fc1.bias: Frozen
# stages.2.1.transformer.0.mlp.fc2.weight: Frozen
# stages.2.1.transformer.0.mlp.fc2.bias: Frozen
# stages.2.1.transformer.1.norm1.weight: Frozen
# stages.2.1.transformer.1.norm1.bias: Frozen
# stages.2.1.transformer.1.attn.qkv.weight: Frozen
# stages.2.1.transformer.1.attn.qkv.bias: Frozen
# stages.2.1.transformer.1.attn.proj.weight: Frozen
# stages.2.1.transformer.1.attn.proj.bias: Frozen
# stages.2.1.transformer.1.norm2.weight: Frozen
# stages.2.1.transformer.1.norm2.bias: Frozen
# stages.2.1.transformer.1.mlp.fc1.weight: Frozen
# stages.2.1.transformer.1.mlp.fc1.bias: Frozen
# stages.2.1.transformer.1.mlp.fc2.weight: Frozen
# stages.2.1.transformer.1.mlp.fc2.bias: Frozen
# stages.2.1.norm.weight: Frozen
# stages.2.1.norm.bias: Frozen
# stages.2.1.conv_proj.conv.weight: Frozen
# stages.2.1.conv_proj.bn.weight: Frozen
# stages.2.1.conv_proj.bn.bias: Frozen
# stages.2.1.conv_fusion.conv.weight: Frozen
# stages.2.1.conv_fusion.bn.weight: Frozen
# stages.2.1.conv_fusion.bn.bias: Frozen
# stages.3.0.conv1_1x1.conv.weight: Frozen
# stages.3.0.conv1_1x1.bn.weight: Frozen
# stages.3.0.conv1_1x1.bn.bias: Frozen
# stages.3.0.conv2_kxk.conv.weight: Frozen
# stages.3.0.conv2_kxk.bn.weight: Frozen
# stages.3.0.conv2_kxk.bn.bias: Frozen
# stages.3.0.conv3_1x1.conv.weight: Frozen
# stages.3.0.conv3_1x1.bn.weight: Frozen
# stages.3.0.conv3_1x1.bn.bias: Frozen
# stages.3.1.conv_kxk.conv.weight: Frozen
# stages.3.1.conv_kxk.bn.weight: Frozen
# stages.3.1.conv_kxk.bn.bias: Frozen
# stages.3.1.conv_1x1.weight: Frozen
# stages.3.1.transformer.0.norm1.weight: Frozen
# stages.3.1.transformer.0.norm1.bias: Frozen
# stages.3.1.transformer.0.attn.qkv.weight: Frozen
# stages.3.1.transformer.0.attn.qkv.bias: Frozen
# stages.3.1.transformer.0.attn.proj.weight: Frozen
# stages.3.1.transformer.0.attn.proj.bias: Frozen
# stages.3.1.transformer.0.norm2.weight: Frozen
# stages.3.1.transformer.0.norm2.bias: Frozen
# stages.3.1.transformer.0.mlp.fc1.weight: Frozen
# stages.3.1.transformer.0.mlp.fc1.bias: Frozen
# stages.3.1.transformer.0.mlp.fc2.weight: Frozen
# stages.3.1.transformer.0.mlp.fc2.bias: Frozen
# stages.3.1.transformer.1.norm1.weight: Frozen
# stages.3.1.transformer.1.norm1.bias: Frozen
# stages.3.1.transformer.1.attn.qkv.weight: Frozen
# stages.3.1.transformer.1.attn.qkv.bias: Frozen
# stages.3.1.transformer.1.attn.proj.weight: Frozen
# stages.3.1.transformer.1.attn.proj.bias: Frozen
# stages.3.1.transformer.1.norm2.weight: Frozen
# stages.3.1.transformer.1.norm2.bias: Frozen
# stages.3.1.transformer.1.mlp.fc1.weight: Frozen
# stages.3.1.transformer.1.mlp.fc1.bias: Frozen
# stages.3.1.transformer.1.mlp.fc2.weight: Frozen
# stages.3.1.transformer.1.mlp.fc2.bias: Frozen
# stages.3.1.transformer.2.norm1.weight: Frozen
# stages.3.1.transformer.2.norm1.bias: Frozen
# stages.3.1.transformer.2.attn.qkv.weight: Frozen
# stages.3.1.transformer.2.attn.qkv.bias: Frozen
# stages.3.1.transformer.2.attn.proj.weight: Frozen
# stages.3.1.transformer.2.attn.proj.bias: Frozen
# stages.3.1.transformer.2.norm2.weight: Frozen
# stages.3.1.transformer.2.norm2.bias: Frozen
# stages.3.1.transformer.2.mlp.fc1.weight: Frozen
# stages.3.1.transformer.2.mlp.fc1.bias: Frozen
# stages.3.1.transformer.2.mlp.fc2.weight: Frozen
# stages.3.1.transformer.2.mlp.fc2.bias: Frozen
# stages.3.1.transformer.3.norm1.weight: Frozen
# stages.3.1.transformer.3.norm1.bias: Frozen
# stages.3.1.transformer.3.attn.qkv.weight: Frozen
# stages.3.1.transformer.3.attn.qkv.bias: Frozen
# stages.3.1.transformer.3.attn.proj.weight: Frozen
# stages.3.1.transformer.3.attn.proj.bias: Frozen
# stages.3.1.transformer.3.norm2.weight: Frozen
# stages.3.1.transformer.3.norm2.bias: Frozen
# stages.3.1.transformer.3.mlp.fc1.weight: Frozen
# stages.3.1.transformer.3.mlp.fc1.bias: Frozen
# stages.3.1.transformer.3.mlp.fc2.weight: Frozen
# stages.3.1.transformer.3.mlp.fc2.bias: Frozen
# stages.3.1.norm.weight: Frozen
# stages.3.1.norm.bias: Frozen
# stages.3.1.conv_proj.conv.weight: Frozen
# stages.3.1.conv_proj.bn.weight: Frozen
# stages.3.1.conv_proj.bn.bias: Frozen
# stages.3.1.conv_fusion.conv.weight: Frozen
# stages.3.1.conv_fusion.bn.weight: Frozen
# stages.3.1.conv_fusion.bn.bias: Frozen
# stages.4.0.conv1_1x1.conv.weight: Frozen
# stages.4.0.conv1_1x1.bn.weight: Frozen
# stages.4.0.conv1_1x1.bn.bias: Frozen
# stages.4.0.conv2_kxk.conv.weight: Frozen
# stages.4.0.conv2_kxk.bn.weight: Frozen
# stages.4.0.conv2_kxk.bn.bias: Frozen
# stages.4.0.conv3_1x1.conv.weight: Frozen
# stages.4.0.conv3_1x1.bn.weight: Frozen
# stages.4.0.conv3_1x1.bn.bias: Frozen
# stages.4.1.conv_kxk.conv.weight: Frozen
# stages.4.1.conv_kxk.bn.weight: Frozen
# stages.4.1.conv_kxk.bn.bias: Frozen
# stages.4.1.conv_1x1.weight: Frozen
# stages.4.1.transformer.0.norm1.weight: Frozen
# stages.4.1.transformer.0.norm1.bias: Frozen
# stages.4.1.transformer.0.attn.qkv.weight: Frozen
# stages.4.1.transformer.0.attn.qkv.bias: Frozen
# stages.4.1.transformer.0.attn.proj.weight: Frozen
# stages.4.1.transformer.0.attn.proj.bias: Frozen
# stages.4.1.transformer.0.norm2.weight: Frozen
# stages.4.1.transformer.0.norm2.bias: Frozen
# stages.4.1.transformer.0.mlp.fc1.weight: Frozen
# stages.4.1.transformer.0.mlp.fc1.bias: Frozen
# stages.4.1.transformer.0.mlp.fc2.weight: Frozen
# stages.4.1.transformer.0.mlp.fc2.bias: Frozen
# stages.4.1.transformer.1.norm1.weight: Frozen
# stages.4.1.transformer.1.norm1.bias: Frozen
# stages.4.1.transformer.1.attn.qkv.weight: Frozen
# stages.4.1.transformer.1.attn.qkv.bias: Frozen
# stages.4.1.transformer.1.attn.proj.weight: Frozen
# stages.4.1.transformer.1.attn.proj.bias: Frozen
# stages.4.1.transformer.1.norm2.weight: Frozen
# stages.4.1.transformer.1.norm2.bias: Frozen
# stages.4.1.transformer.1.mlp.fc1.weight: Frozen
# stages.4.1.transformer.1.mlp.fc1.bias: Frozen
# stages.4.1.transformer.1.mlp.fc2.weight: Frozen
# stages.4.1.transformer.1.mlp.fc2.bias: Frozen
# stages.4.1.transformer.2.norm1.weight: Frozen
# stages.4.1.transformer.2.norm1.bias: Frozen
# stages.4.1.transformer.2.attn.qkv.weight: Frozen
# stages.4.1.transformer.2.attn.qkv.bias: Frozen
# stages.4.1.transformer.2.attn.proj.weight: Frozen
# stages.4.1.transformer.2.attn.proj.bias: Frozen
# stages.4.1.transformer.2.norm2.weight: Frozen
# stages.4.1.transformer.2.norm2.bias: Frozen
# stages.4.1.transformer.2.mlp.fc1.weight: Frozen
# stages.4.1.transformer.2.mlp.fc1.bias: Frozen
# stages.4.1.transformer.2.mlp.fc2.weight: Frozen
# stages.4.1.transformer.2.mlp.fc2.bias: Frozen
# stages.4.1.norm.weight: Frozen
# stages.4.1.norm.bias: Frozen
# stages.4.1.conv_proj.conv.weight: Frozen
# stages.4.1.conv_proj.bn.weight: Trainable
# stages.4.1.conv_proj.bn.bias: Trainable
# stages.4.1.conv_fusion.conv.weight: Trainable
# stages.4.1.conv_fusion.bn.weight: Trainable
# stages.4.1.conv_fusion.bn.bias: Trainable
# final_conv.conv.weight: Trainable
# final_conv.bn.weight: Trainable
# final_conv.bn.bias: Trainable
# head.2.weight: Trainable
# head.2.bias: Trainable
# head.5.weight: Trainable
# head.5.bias: Trainable

# %%
# !unzip /content/FBinaryMSLD.zip -d dataset
# Out:
# Archive:  /content/FBinaryMSLD.zip
#    creating: dataset/Train/
#    creating: dataset/Train/Monkeypox/
#   inflating: dataset/Train/Monkeypox/M01_01_00.jpg
#   inflating: dataset/Train/Monkeypox/M01_01_01.jpg
#   inflating: dataset/Train/Monkeypox/M01_01_02.jpg
#   inflating: dataset/Train/Monkeypox/M01_01_03.jpg
#   inflating: dataset/Train/Monkeypox/M01_01_04.jpg
#   inflating: dataset/Train/Monkeypox/M01_01_05.jpg
#   inflating: dataset/Train/Monkeypox/M01_01_06.jpg
#   inflating: dataset/Train/Monkeypox/M01_01_07.jpg
#   inflating: dataset/Train/Monkeypox/M01_01_08.jpg
#   inflating: dataset/Train/Monkeypox/M01_01_09.jpg
#   inflating: dataset/Train/Monkeypox/M01_01_10.jpg
#   inflating: dataset/Train/Monkeypox/M01_01_11.jpg
#   inflating: dataset/Train/Monkeypox/M01_01_12.jpg
#   inflating: dataset/Train/Monkeypox/M01_01_13.jpg
#   inflating: dataset/Train/Monkeypox/M01_02_00.jpg
#   inflating: dataset/Train/Monkeypox/M01_02_01.jpg
#   inflating: dataset/Train/Monkeypox/M01_02_02.jpg
#   inflating: dataset/Train/Monkeypox/M01_02_03.jpg
#   inflating: dataset/Train/Monkeypox/M01_02_04.jpg
#   inflating: dataset/Train/Monkeypox/M01_02_05.jpg
#   inflating: dataset/Train/Monkeypox/M01_02_06.jpg
#   inflating: dataset/Train/Monkeypox/M01_02_07.jpg
#   inflating: dataset/Train/Monkeypox/M01_02_08.jpg
#   inflating: dataset/Train/Monkeypox/M01_02_09.jpg
#   inflating: dataset/Train/Monkeypox/M01_02_10.jpg
#   inflating: dataset/Train/Monkeypox/M01_02_11.jpg
#   inflating: dataset/Train/Monkeypox/M01_02_12.jpg
#   inflating: dataset/Train/Monkeypox/M01_02_13.jpg
#   inflating: dataset/Train/Monkeypox/M01_03_00.jpg
#   inflating: dataset/Train/Monkeypox/M01_03_01.jpg
#   inflating: dataset/Train/Monkeypox/M01_03_02.jpg
#   inflating: dataset/Train/Monkeypox/M01_03_03.jpg
#   inflating: dataset/Train/Monkeypox/M01_03_04.jpg
#   inflating: dataset/Train/Monkeypox/M01_03_05.jpg
#   inflating: dataset/Train/Monkeypox/M01_03_06.jpg
#   inflating: dataset/Train/Monkeypox/M01_03_07.jpg
#   inflating: dataset/Train/Monkeypox/M01_03_08.jpg
#   inflating: dataset/Train/Monkeypox/M01_03_09.jpg
#   inflating: dataset/Train/Monkeypox/M01_03_10.jpg
#   inflating: dataset/Train/Monkeypox/M01_03_11.jpg
#   inflating: dataset/Train/Monkeypox/M01_03_12.jpg
#   inflating: dataset/Train/Monkeypox/M01_03_13.jpg
#   inflating: dataset/Train/Monkeypox/M01_04_00.jpg
#   inflating: dataset/Train/Monkeypox/M01_04_01.jpg
#   inflating: dataset/Train/Monkeypox/M01_04_02.jpg
#   inflating: dataset/Train/Monkeypox/M01_04_03.jpg
#   inflating: dataset/Train/Monkeypox/M01_04_04.jpg
#   inflating: dataset/Train/Monkeypox/M01_04_05.jpg
#   inflating: dataset/Train/Monkeypox/M01_04_06.jpg
#   inflating: dataset/Train/Monkeypox/M01_04_07.jpg
#   inflating: dataset/Train/Monkeypox/M01_04_08.jpg
#   inflating: dataset/Train/Monkeypox/M01_04_09.jpg
#   inflating: dataset/Train/Monkeypox/M01_04_10.jpg
#   inflating: dataset/Train/Monkeypox/M01_04_11.jpg
#   inflating: dataset/Train/Monkeypox/M01_04_12.jpg
#   inflating: dataset/Train/Monkeypox/M01_04_13.jpg
#   inflating: dataset/Train/Monkeypox/M02_01_00.jpg
#   inflating: dataset/Train/Monkeypox/M02_01_01.jpg
#   inflating: dataset/Train/Monkeypox/M02_01_02.jpg
#   inflating: dataset/Train/Monkeypox/M02_01_03.jpg
#   inflating: dataset/Train/Monkeypox/M02_01_04.jpg
#   inflating: dataset/Train/Monkeypox/M02_01_05.jpg
#   inflating: dataset/Train/Monkeypox/M02_01_06.jpg
#   inflating: dataset/Train/Monkeypox/M02_01_07.jpg
#   inflating: dataset/Train/Monkeypox/M02_01_08.jpg
#   inflating: dataset/Train/Monkeypox/M02_01_09.jpg
#   inflating: dataset/Train/Monkeypox/M02_01_10.jpg
#   inflating: dataset/Train/Monkeypox/M02_01_11.jpg
#   inflating: dataset/Train/Monkeypox/M02_01_12.jpg
#   inflating: dataset/Train/Monkeypox/M02_01_13.jpg
#   inflating: dataset/Train/Monkeypox/M02_02_00.jpg
#   inflating: dataset/Train/Monkeypox/M02_02_01.jpg
#   inflating: dataset/Train/Monkeypox/M02_02_02.jpg
#   inflating: dataset/Train/Monkeypox/M02_02_03.jpg
#   inflating: dataset/Train/Monkeypox/M02_02_04.jpg
#   inflating: dataset/Train/Monkeypox/M02_02_05.jpg
#   inflating: dataset/Train/Monkeypox/M02_02_06.jpg
#   inflating: dataset/Train/Monkeypox/M02_02_07.jpg
#   inflating: dataset/Train/Monkeypox/M02_02_08.jpg
#   inflating: dataset/Train/Monkeypox/M02_02_09.jpg
#   inflating: dataset/Train/Monkeypox/M02_02_10.jpg
#   inflating: dataset/Train/Monkeypox/M02_02_11.jpg
#   inflating: dataset/Train/Monkeypox/M02_02_12.jpg
#   inflating: dataset/Train/Monkeypox/M02_02_13.jpg
#   inflating: dataset/Train/Monkeypox/M03_01_00.jpg
#   inflating: dataset/Train/Monkeypox/M03_01_01.jpg
#   inflating: dataset/Train/Monkeypox/M03_01_02.jpg
#   inflating: dataset/Train/Monkeypox/M03_01_03.jpg
#   inflating: dataset/Train/Monkeypox/M03_01_04.jpg
#   inflating: dataset/Train/Monkeypox/M03_01_05.jpg
#   inflating: dataset/Train/Monkeypox/M03_01_06.jpg
#   inflating: dataset/Train/Monkeypox/M03_01_07.jpg
#   inflating: dataset/Train/Monkeypox/M03_01_08.jpg
#   inflating: dataset/Train/Monkeypox/M03_01_09.jpg
#   inflating: dataset/Train/Monkeypox/M03_01_10.jpg
#   inflating: dataset/Train/Monkeypox/M03_01_11.jpg
#   inflating: dataset/Train/Monkeypox/M03_01_12.jpg
#   inflating: dataset/Train/Monkeypox/M03_01_13.jpg
#   inflating: dataset/Train/Monkeypox/M05_01_00.jpg
#   inflating: dataset/Train/Monkeypox/M05_01_01.jpg
#   inflating: dataset/Train/Monkeypox/M05_01_02.jpg
#   inflating: dataset/Train/Monkeypox/M05_01_03.jpg
#   inflating: dataset/Train/Monkeypox/M05_01_04.jpg
#   inflating: dataset/Train/Monkeypox/M05_01_05.jpg
#   inflating: dataset/Train/Monkeypox/M05_01_06.jpg
#   inflating: dataset/Train/Monkeypox/M05_01_07.jpg
#   inflating: dataset/Train/Monkeypox/M05_01_08.jpg
#   inflating: dataset/Train/Monkeypox/M05_01_09.jpg
#   inflating: dataset/Train/Monkeypox/M05_01_10.jpg
#   inflating: dataset/Train/Monkeypox/M05_01_11.jpg
#   inflating: dataset/Train/Monkeypox/M05_01_12.jpg
#   inflating: dataset/Train/Monkeypox/M05_01_13.jpg
#   inflating: dataset/Train/Monkeypox/M05_02_00.jpg
#   inflating: dataset/Train/Monkeypox/M05_02_01.jpg
#   inflating: dataset/Train/Monkeypox/M05_02_02.jpg
#   inflating: dataset/Train/Monkeypox/M05_02_03.jpg
#   inflating: dataset/Train/Monkeypox/M05_02_04.jpg
#   inflating: dataset/Train/Monkeypox/M05_02_05.jpg
#   inflating: dataset/Train/Monkeypox/M05_02_06.jpg
#   inflating: dataset/Train/Monkeypox/M05_02_07.jpg
#   inflating: dataset/Train/Monkeypox/M05_02_08.jpg
#   inflating: dataset/Train/Monkeypox/M05_02_09.jpg
#   inflating: dataset/Train/Monkeypox/M05_02_10.jpg
#   inflating: dataset/Train/Monkeypox/M05_02_11.jpg
#   inflating: dataset/Train/Monkeypox/M05_02_12.jpg
#   inflating: dataset/Train/Monkeypox/M05_02_13.jpg
#   inflating: dataset/Train/Monkeypox/M06_01_00.jpg
#   inflating: dataset/Train/Monkeypox/M06_01_01.jpg
#   inflating: dataset/Train/Monkeypox/M06_01_02.jpg
#   inflating: dataset/Train/Monkeypox/M06_01_03.jpg
#   inflating: dataset/Train/Monkeypox/M06_01_04.jpg
#   inflating: dataset/Train/Monkeypox/M06_01_05.jpg
#   inflating: dataset/Train/Monkeypox/M06_01_06.jpg
#   inflating: dataset/Train/Monkeypox/M06_01_07.jpg
#   inflating: dataset/Train/Monkeypox/M06_01_08.jpg
#   inflating: dataset/Train/Monkeypox/M06_01_09.jpg
#   inflating: dataset/Train/Monkeypox/M06_01_10.jpg
#   inflating: dataset/Train/Monkeypox/M06_01_11.jpg
#   inflating: dataset/Train/Monkeypox/M06_01_12.jpg
#   inflating: dataset/Train/Monkeypox/M06_01_13.jpg
#   inflating: dataset/Train/Monkeypox/M06_02_00.jpg
#   inflating: dataset/Train/Monkeypox/M06_02_01.jpg
#   inflating: dataset/Train/Monkeypox/M06_02_02.jpg
#   inflating: dataset/Train/Monkeypox/M06_02_03.jpg
#   inflating: dataset/Train/Monkeypox/M06_02_04.jpg
#   inflating: dataset/Train/Monkeypox/M06_02_05.jpg
#   inflating: dataset/Train/Monkeypox/M06_02_06.jpg
#   inflating: dataset/Train/Monkeypox/M06_02_07.jpg
#   inflating: dataset/Train/Monkeypox/M06_02_08.jpg
#   inflating: dataset/Train/Monkeypox/M06_02_09.jpg
#   inflating: dataset/Train/Monkeypox/M06_02_10.jpg
#   inflating: dataset/Train/Monkeypox/M06_02_11.jpg
#   inflating: dataset/Train/Monkeypox/M06_02_12.jpg
#   inflating: dataset/Train/Monkeypox/M06_02_13.jpg
#   inflating: dataset/Train/Monkeypox/M07_01_00.jpg
#   inflating: dataset/Train/Monkeypox/M07_01_01.jpg
#   inflating: dataset/Train/Monkeypox/M07_01_02.jpg
#   inflating: dataset/Train/Monkeypox/M07_01_03.jpg
#   inflating: dataset/Train/Monkeypox/M07_01_04.jpg
#   inflating: dataset/Train/Monkeypox/M07_01_05.jpg
#   inflating: dataset/Train/Monkeypox/M07_01_06.jpg
#   inflating: dataset/Train/Monkeypox/M07_01_07.jpg
#   inflating: dataset/Train/Monkeypox/M07_01_08.jpg
#   inflating: dataset/Train/Monkeypox/M07_01_09.jpg
#   inflating: dataset/Train/Monkeypox/M07_01_10.jpg
#   inflating: dataset/Train/Monkeypox/M07_01_11.jpg
#   inflating: dataset/Train/Monkeypox/M07_01_12.jpg
#   inflating: dataset/Train/Monkeypox/M07_01_13.jpg
#   inflating: dataset/Train/Monkeypox/M08_01_00.jpg
#   inflating: dataset/Train/Monkeypox/M08_01_01.jpg
#   inflating: dataset/Train/Monkeypox/M08_01_02.jpg
#   inflating: dataset/Train/Monkeypox/M08_01_03.jpg
#   inflating: dataset/Train/Monkeypox/M08_01_04.jpg
#   inflating: dataset/Train/Monkeypox/M08_01_05.jpg
#   inflating: dataset/Train/Monkeypox/M08_01_06.jpg
#   inflating: dataset/Train/Monkeypox/M08_01_07.jpg
#   inflating: dataset/Train/Monkeypox/M08_01_08.jpg
#   inflating: dataset/Train/Monkeypox/M08_01_09.jpg
#   inflating: dataset/Train/Monkeypox/M08_01_10.jpg
#   inflating: dataset/Train/Monkeypox/M08_01_11.jpg
#   inflating: dataset/Train/Monkeypox/M08_01_12.jpg
#   inflating: dataset/Train/Monkeypox/M08_01_13.jpg
#   inflating: dataset/Train/Monkeypox/M09_01_00.jpg
#   inflating: dataset/Train/Monkeypox/M09_01_01.jpg
#   inflating: dataset/Train/Monkeypox/M09_01_02.jpg
#   inflating: dataset/Train/Monkeypox/M09_01_03.jpg
#   inflating: dataset/Train/Monkeypox/M09_01_04.jpg
#   inflating: dataset/Train/Monkeypox/M09_01_05.jpg
#   inflating: dataset/Train/Monkeypox/M09_01_06.jpg
#   inflating: dataset/Train/Monkeypox/M09_01_07.jpg
#   inflating: dataset/Train/Monkeypox/M09_01_08.jpg
#   inflating: dataset/Train/Monkeypox/M09_01_09.jpg
#   inflating: dataset/Train/Monkeypox/M09_01_10.jpg
#   inflating: dataset/Train/Monkeypox/M09_01_11.jpg
#   inflating: dataset/Train/Monkeypox/M09_01_12.jpg
#   inflating: dataset/Train/Monkeypox/M09_01_13.jpg
#   inflating: dataset/Train/Monkeypox/M09_02_00.jpg
#   inflating: dataset/Train/Monkeypox/M09_02_01.jpg
#   inflating: dataset/Train/Monkeypox/M09_02_02.jpg
#   inflating: dataset/Train/Monkeypox/M09_02_03.jpg
#   inflating: dataset/Train/Monkeypox/M09_02_04.jpg
#   inflating: dataset/Train/Monkeypox/M09_02_05.jpg
#   inflating: dataset/Train/Monkeypox/M09_02_06.jpg
#   inflating: dataset/Train/Monkeypox/M09_02_07.jpg
#   inflating: dataset/Train/Monkeypox/M09_02_08.jpg
#   inflating: dataset/Train/Monkeypox/M09_02_09.jpg
#   inflating: dataset/Train/Monkeypox/M09_02_10.jpg
#   inflating: dataset/Train/Monkeypox/M09_02_11.jpg
#   inflating: dataset/Train/Monkeypox/M09_02_12.jpg
#   inflating: dataset/Train/Monkeypox/M09_02_13.jpg
#   inflating: dataset/Train/Monkeypox/M09_03_00.jpg
#   inflating: dataset/Train/Monkeypox/M09_03_01.jpg
#   inflating: dataset/Train/Monkeypox/M09_03_02.jpg
#   inflating: dataset/Train/Monkeypox/M09_03_03.jpg
#   inflating: dataset/Train/Monkeypox/M09_03_04.jpg
#   inflating: dataset/Train/Monkeypox/M09_03_05.jpg
#   inflating: dataset/Train/Monkeypox/M09_03_06.jpg
#   inflating: dataset/Train/Monkeypox/M09_03_07.jpg
#   inflating: dataset/Train/Monkeypox/M09_03_08.jpg
#   inflating: dataset/Train/Monkeypox/M09_03_09.jpg
#   inflating: dataset/Train/Monkeypox/M09_03_10.jpg
#   inflating: dataset/Train/Monkeypox/M09_03_11.jpg
#   inflating: dataset/Train/Monkeypox/M09_03_12.jpg
#   inflating: dataset/Train/Monkeypox/M09_03_13.jpg
#   inflating: dataset/Train/Monkeypox/M09_04_00.jpg
#   inflating: dataset/Train/Monkeypox/M09_04_01.jpg
#   inflating: dataset/Train/Monkeypox/M09_04_02.jpg
#   inflating: dataset/Train/Monkeypox/M09_04_03.jpg
#   inflating: dataset/Train/Monkeypox/M09_04_04.jpg
#   inflating: dataset/Train/Monkeypox/M09_04_05.jpg
#   inflating: dataset/Train/Monkeypox/M09_04_06.jpg
#   inflating: dataset/Train/Monkeypox/M09_04_07.jpg
#   inflating: dataset/Train/Monkeypox/M09_04_08.jpg
#   inflating: dataset/Train/Monkeypox/M09_04_09.jpg
#   inflating: dataset/Train/Monkeypox/M09_04_10.jpg
#   inflating: dataset/Train/Monkeypox/M09_04_11.jpg
#   inflating: dataset/Train/Monkeypox/M09_04_12.jpg
#   inflating: dataset/Train/Monkeypox/M09_04_13.jpg
#   inflating: dataset/Train/Monkeypox/M10_01_00.jpg
#   inflating: dataset/Train/Monkeypox/M10_01_01.jpg
#   inflating: dataset/Train/Monkeypox/M10_01_02.jpg
#   inflating: dataset/Train/Monkeypox/M10_01_03.jpg
#   inflating: dataset/Train/Monkeypox/M10_01_04.jpg
#   inflating: dataset/Train/Monkeypox/M10_01_05.jpg
#   inflating: dataset/Train/Monkeypox/M10_01_06.jpg
#   inflating: dataset/Train/Monkeypox/M10_01_07.jpg
#   inflating: dataset/Train/Monkeypox/M10_01_08.jpg
#   inflating: dataset/Train/Monkeypox/M10_01_09.jpg
#   inflating: dataset/Train/Monkeypox/M10_01_10.jpg
#   inflating: dataset/Train/Monkeypox/M10_01_11.jpg
#   inflating: dataset/Train/Monkeypox/M10_01_12.jpg
#   inflating: dataset/Train/Monkeypox/M10_01_13.jpg
#   inflating: dataset/Train/Monkeypox/M10_02_00.jpg
#   inflating: dataset/Train/Monkeypox/M10_02_01.jpg
#   inflating: dataset/Train/Monkeypox/M10_02_02.jpg
#   inflating: dataset/Train/Monkeypox/M10_02_03.jpg
#   inflating: dataset/Train/Monkeypox/M10_02_04.jpg
#   inflating: dataset/Train/Monkeypox/M10_02_05.jpg
#   inflating: dataset/Train/Monkeypox/M10_02_06.jpg
#   inflating: dataset/Train/Monkeypox/M10_02_07.jpg
#   inflating: dataset/Train/Monkeypox/M10_02_08.jpg
#   inflating: dataset/Train/Monkeypox/M10_02_09.jpg
#   inflating: dataset/Train/Monkeypox/M10_02_10.jpg
#   inflating: dataset/Train/Monkeypox/M10_02_11.jpg
#   inflating: dataset/Train/Monkeypox/M10_02_12.jpg
#   inflating: dataset/Train/Monkeypox/M10_02_13.jpg
#   inflating: dataset/Train/Monkeypox/M11_01_00.jpg
#   inflating: dataset/Train/Monkeypox/M11_01_01.jpg
#   inflating: dataset/Train/Monkeypox/M11_01_02.jpg
#   inflating: dataset/Train/Monkeypox/M11_01_03.jpg
#   inflating: dataset/Train/Monkeypox/M11_01_04.jpg
#   inflating: dataset/Train/Monkeypox/M11_01_05.jpg
#   inflating: dataset/Train/Monkeypox/M11_01_06.jpg
#   inflating: dataset/Train/Monkeypox/M11_01_07.jpg
#   inflating: dataset/Train/Monkeypox/M11_01_08.jpg
#   inflating: dataset/Train/Monkeypox/M11_01_09.jpg
#   inflating: dataset/Train/Monkeypox/M11_01_10.jpg
#   inflating: dataset/Train/Monkeypox/M11_01_11.jpg
#   inflating: dataset/Train/Monkeypox/M11_01_12.jpg
#   inflating: dataset/Train/Monkeypox/M11_01_13.jpg
#   inflating: dataset/Train/Monkeypox/M12_01_00.jpg
#   inflating: dataset/Train/Monkeypox/M12_01_01.jpg
#   inflating: dataset/Train/Monkeypox/M12_01_02.jpg
#   inflating: dataset/Train/Monkeypox/M12_01_03.jpg
#   inflating: dataset/Train/Monkeypox/M12_01_04.jpg
#   inflating: dataset/Train/Monkeypox/M12_01_05.jpg
#   inflating: dataset/Train/Monkeypox/M12_01_06.jpg
#   inflating: dataset/Train/Monkeypox/M12_01_07.jpg
#   inflating: dataset/Train/Monkeypox/M12_01_08.jpg
#   inflating: dataset/Train/Monkeypox/M12_01_09.jpg
#   inflating: dataset/Train/Monkeypox/M12_01_10.jpg
#   inflating: dataset/Train/Monkeypox/M12_01_11.jpg
#   inflating: dataset/Train/Monkeypox/M12_01_12.jpg
#   inflating: dataset/Train/Monkeypox/M12_01_13.jpg
#   inflating: dataset/Train/Monkeypox/M13_01_00.jpg
#   inflating: dataset/Train/Monkeypox/M13_01_01.jpg
#   inflating: dataset/Train/Monkeypox/M13_01_02.jpg
#   inflating: dataset/Train/Monkeypox/M13_01_03.jpg
#   inflating: dataset/Train/Monkeypox/M13_01_04.jpg
#   inflating: dataset/Train/Monkeypox/M13_01_05.jpg
#   inflating: dataset/Train/Monkeypox/M13_01_06.jpg
#   inflating: dataset/Train/Monkeypox/M13_01_07.jpg
#   inflating: dataset/Train/Monkeypox/M13_01_08.jpg
#   inflating: dataset/Train/Monkeypox/M13_01_09.jpg
#   inflating: dataset/Train/Monkeypox/M13_01_10.jpg
#   inflating: dataset/Train/Monkeypox/M13_01_11.jpg
#   inflating: dataset/Train/Monkeypox/M13_01_12.jpg
#   inflating: dataset/Train/Monkeypox/M13_01_13.jpg
#   inflating: dataset/Train/Monkeypox/M14_01_00.jpg
#   inflating: dataset/Train/Monkeypox/M14_01_01.jpg
#   inflating: dataset/Train/Monkeypox/M14_01_02.jpg
#   inflating: dataset/Train/Monkeypox/M14_01_03.jpg
#   inflating: dataset/Train/Monkeypox/M14_01_04.jpg
#   inflating: dataset/Train/Monkeypox/M14_01_05.jpg
#   inflating: dataset/Train/Monkeypox/M14_01_06.jpg
#   inflating: dataset/Train/Monkeypox/M14_01_07.jpg
#   inflating: dataset/Train/Monkeypox/M14_01_08.jpg
#   inflating: dataset/Train/Monkeypox/M14_01_09.jpg
#   inflating: dataset/Train/Monkeypox/M14_01_10.jpg
#   inflating: dataset/Train/Monkeypox/M14_01_11.jpg
#   inflating: dataset/Train/Monkeypox/M14_01_12.jpg
#   inflating: dataset/Train/Monkeypox/M14_01_13.jpg
#   inflating: dataset/Train/Monkeypox/M15_01_00.jpg
#   inflating: dataset/Train/Monkeypox/M15_01_01.jpg
#   inflating: dataset/Train/Monkeypox/M15_01_02.jpg
#   inflating: dataset/Train/Monkeypox/M15_01_03.jpg
#   inflating: dataset/Train/Monkeypox/M15_01_04.jpg
#   inflating: dataset/Train/Monkeypox/M15_01_05.jpg
#   inflating: dataset/Train/Monkeypox/M15_01_06.jpg
#   inflating: dataset/Train/Monkeypox/M15_01_07.jpg
#   inflating: dataset/Train/Monkeypox/M15_01_08.jpg
#   inflating: dataset/Train/Monkeypox/M15_01_09.jpg
#   inflating: dataset/Train/Monkeypox/M15_01_10.jpg
#   inflating: dataset/Train/Monkeypox/M15_01_11.jpg
#   inflating: dataset/Train/Monkeypox/M15_01_12.jpg
#   inflating: dataset/Train/Monkeypox/M15_01_13.jpg
#   inflating: dataset/Train/Monkeypox/M16_01_00.jpg
#   inflating: dataset/Train/Monkeypox/M16_01_01.jpg
#   inflating: dataset/Train/Monkeypox/M16_01_02.jpg
#   inflating: dataset/Train/Monkeypox/M16_01_03.jpg
#   inflating: dataset/Train/Monkeypox/M16_01_04.jpg
#   inflating: dataset/Train/Monkeypox/M16_01_05.jpg
#   inflating: dataset/Train/Monkeypox/M16_01_06.jpg
#   inflating: dataset/Train/Monkeypox/M16_01_07.jpg
#   inflating: dataset/Train/Monkeypox/M16_01_08.jpg
#   inflating: dataset/Train/Monkeypox/M16_01_09.jpg
#   inflating: dataset/Train/Monkeypox/M16_01_10.jpg
#   inflating: dataset/Train/Monkeypox/M16_01_11.jpg
#   inflating: dataset/Train/Monkeypox/M16_01_12.jpg
#   inflating: dataset/Train/Monkeypox/M16_01_13.jpg
#   inflating: dataset/Train/Monkeypox/M17_01_00.jpg
#   inflating: dataset/Train/Monkeypox/M17_01_01.jpg
#   inflating: dataset/Train/Monkeypox/M17_01_02.jpg
#   inflating: dataset/Train/Monkeypox/M17_01_03.jpg
#   inflating: dataset/Train/Monkeypox/M17_01_04.jpg
#   inflating: dataset/Train/Monkeypox/M17_01_05.jpg
#   inflating: dataset/Train/Monkeypox/M17_01_06.jpg
#   inflating: dataset/Train/Monkeypox/M17_01_07.jpg
#   inflating: dataset/Train/Monkeypox/M17_01_08.jpg
#   inflating: dataset/Train/Monkeypox/M17_01_09.jpg
#   inflating: dataset/Train/Monkeypox/M17_01_10.jpg
#   inflating: dataset/Train/Monkeypox/M17_01_11.jpg
#   inflating: dataset/Train/Monkeypox/M17_01_12.jpg
#   inflating: dataset/Train/Monkeypox/M17_01_13.jpg
#   inflating: dataset/Train/Monkeypox/M17_02_00.jpg
#   inflating: dataset/Train/Monkeypox/M17_02_01.jpg
#   inflating: dataset/Train/Monkeypox/M17_02_02.jpg
#   inflating: dataset/Train/Monkeypox/M17_02_03.jpg
#   inflating: dataset/Train/Monkeypox/M17_02_04.jpg
#   inflating: dataset/Train/Monkeypox/M17_02_05.jpg
#   inflating: dataset/Train/Monkeypox/M17_02_06.jpg
#   inflating: dataset/Train/Monkeypox/M17_02_07.jpg
#   inflating: dataset/Train/Monkeypox/M17_02_08.jpg
#   inflating: dataset/Train/Monkeypox/M17_02_09.jpg
#   inflating: dataset/Train/Monkeypox/M17_02_10.jpg
#   inflating: dataset/Train/Monkeypox/M17_02_11.jpg
#   inflating: dataset/Train/Monkeypox/M17_02_12.jpg
#   inflating: dataset/Train/Monkeypox/M17_02_13.jpg
#   inflating: dataset/Train/Monkeypox/M18_01_00.jpg
#   inflating: dataset/Train/Monkeypox/M18_01_01.jpg
#   inflating: dataset/Train/Monkeypox/M18_01_02.jpg
#   inflating: dataset/Train/Monkeypox/M18_01_03.jpg
#   inflating: dataset/Train/Monkeypox/M18_01_04.jpg
#   inflating: dataset/Train/Monkeypox/M18_01_05.jpg
#   inflating: dataset/Train/Monkeypox/M18_01_06.jpg
#   inflating: dataset/Train/Monkeypox/M18_01_07.jpg
#   inflating: dataset/Train/Monkeypox/M18_01_08.jpg
#   inflating: dataset/Train/Monkeypox/M18_01_09.jpg
#   inflating: dataset/Train/Monkeypox/M18_01_10.jpg
#   inflating: dataset/Train/Monkeypox/M18_01_11.jpg
#   inflating: dataset/Train/Monkeypox/M18_01_12.jpg
#   inflating: dataset/Train/Monkeypox/M18_01_13.jpg
#   inflating: dataset/Train/Monkeypox/M18_02_00.jpg
#   inflating: dataset/Train/Monkeypox/M18_02_01.jpg
#   inflating: dataset/Train/Monkeypox/M18_02_02.jpg
#   inflating: dataset/Train/Monkeypox/M18_02_03.jpg
#   inflating: dataset/Train/Monkeypox/M18_02_04.jpg
#   inflating: dataset/Train/Monkeypox/M18_02_05.jpg
#   inflating: dataset/Train/Monkeypox/M18_02_06.jpg
#   inflating: dataset/Train/Monkeypox/M18_02_07.jpg
#   inflating: dataset/Train/Monkeypox/M18_02_08.jpg
#   inflating: dataset/Train/Monkeypox/M18_02_09.jpg
#   inflating: dataset/Train/Monkeypox/M18_02_10.jpg
#   inflating: dataset/Train/Monkeypox/M18_02_11.jpg
#   inflating: dataset/Train/Monkeypox/M18_02_12.jpg
#   inflating: dataset/Train/Monkeypox/M18_02_13.jpg
#   inflating: dataset/Train/Monkeypox/M20_01_00.jpg
#   inflating: dataset/Train/Monkeypox/M20_01_01.jpg
#   inflating: dataset/Train/Monkeypox/M20_01_02.jpg
#   inflating: dataset/Train/Monkeypox/M20_01_03.jpg
#   inflating: dataset/Train/Monkeypox/M20_01_04.jpg
#   inflating: dataset/Train/Monkeypox/M20_01_05.jpg
#   inflating: dataset/Train/Monkeypox/M20_01_06.jpg
#   inflating: dataset/Train/Monkeypox/M20_01_07.jpg
#   inflating: dataset/Train/Monkeypox/M20_01_08.jpg
#   inflating: dataset/Train/Monkeypox/M20_01_09.jpg
#   inflating: dataset/Train/Monkeypox/M20_01_10.jpg
#   inflating: dataset/Train/Monkeypox/M20_01_11.jpg
#   inflating: dataset/Train/Monkeypox/M20_01_12.jpg
#   inflating: dataset/Train/Monkeypox/M20_01_13.jpg
#   inflating: dataset/Train/Monkeypox/M20_02_00.jpg
#   inflating: dataset/Train/Monkeypox/M20_02_01.jpg
#   inflating: dataset/Train/Monkeypox/M20_02_02.jpg
#   inflating: dataset/Train/Monkeypox/M20_02_03.jpg
#   inflating: dataset/Train/Monkeypox/M20_02_04.jpg
#   inflating: dataset/Train/Monkeypox/M20_02_05.jpg
#   inflating: dataset/Train/Monkeypox/M20_02_06.jpg
#   inflating: dataset/Train/Monkeypox/M20_02_07.jpg
#   inflating: dataset/Train/Monkeypox/M20_02_08.jpg
#   inflating: dataset/Train/Monkeypox/M20_02_09.jpg
#   inflating: dataset/Train/Monkeypox/M20_02_10.jpg
#   inflating: dataset/Train/Monkeypox/M20_02_11.jpg
#   inflating: dataset/Train/Monkeypox/M20_02_12.jpg
#   inflating: dataset/Train/Monkeypox/M20_02_13.jpg
#   inflating: dataset/Train/Monkeypox/M21_01_00.jpg
#   inflating: dataset/Train/Monkeypox/M21_01_01.jpg
#   inflating: dataset/Train/Monkeypox/M21_01_02.jpg
#   inflating: dataset/Train/Monkeypox/M21_01_03.jpg
#   inflating: dataset/Train/Monkeypox/M21_01_04.jpg
#   inflating: dataset/Train/Monkeypox/M21_01_05.jpg
#   inflating: dataset/Train/Monkeypox/M21_01_06.jpg
#   inflating: dataset/Train/Monkeypox/M21_01_07.jpg
#   inflating: dataset/Train/Monkeypox/M21_01_08.jpg
#   inflating: dataset/Train/Monkeypox/M21_01_09.jpg
#   inflating: dataset/Train/Monkeypox/M21_01_10.jpg
#   inflating: dataset/Train/Monkeypox/M21_01_11.jpg
#   inflating: dataset/Train/Monkeypox/M21_01_12.jpg
#   inflating: dataset/Train/Monkeypox/M21_01_13.jpg
#   inflating: dataset/Train/Monkeypox/M21_02_00.jpg
#   inflating: dataset/Train/Monkeypox/M21_02_01.jpg
#   inflating: dataset/Train/Monkeypox/M21_02_02.jpg
#   inflating: dataset/Train/Monkeypox/M21_02_03.jpg
#   inflating: dataset/Train/Monkeypox/M21_02_04.jpg
#   inflating: dataset/Train/Monkeypox/M21_02_05.jpg
#   inflating: dataset/Train/Monkeypox/M21_02_06.jpg
#   inflating: dataset/Train/Monkeypox/M21_02_07.jpg
#   inflating: dataset/Train/Monkeypox/M21_02_08.jpg
#   inflating: dataset/Train/Monkeypox/M21_02_09.jpg
#   inflating: dataset/Train/Monkeypox/M21_02_10.jpg
#   inflating: dataset/Train/Monkeypox/M21_02_11.jpg
#   inflating: dataset/Train/Monkeypox/M21_02_12.jpg
#   inflating: dataset/Train/Monkeypox/M21_02_13.jpg
#   inflating: dataset/Train/Monkeypox/M22_01_00.jpg
#   inflating: dataset/Train/Monkeypox/M22_01_01.jpg
#   inflating: dataset/Train/Monkeypox/M22_01_02.jpg
#   inflating: dataset/Train/Monkeypox/M22_01_03.jpg
#   inflating: dataset/Train/Monkeypox/M22_01_04.jpg
#   inflating: dataset/Train/Monkeypox/M22_01_05.jpg
#   inflating: dataset/Train/Monkeypox/M22_01_06.jpg
#   inflating: dataset/Train/Monkeypox/M22_01_07.jpg
#   inflating: dataset/Train/Monkeypox/M22_01_08.jpg
#   inflating: dataset/Train/Monkeypox/M22_01_09.jpg
#   inflating: dataset/Train/Monkeypox/M22_01_10.jpg
#   inflating: dataset/Train/Monkeypox/M22_01_11.jpg
#   inflating: dataset/Train/Monkeypox/M22_01_12.jpg
#   inflating: dataset/Train/Monkeypox/M22_01_13.jpg
#   inflating: dataset/Train/Monkeypox/M24_01_00.jpg
#   inflating: dataset/Train/Monkeypox/M24_01_01.jpg
#   inflating: dataset/Train/Monkeypox/M24_01_02.jpg
#   inflating: dataset/Train/Monkeypox/M24_01_03.jpg
#   inflating: dataset/Train/Monkeypox/M24_01_04.jpg
#   inflating: dataset/Train/Monkeypox/M24_01_05.jpg
#   inflating: dataset/Train/Monkeypox/M24_01_06.jpg
#   inflating: dataset/Train/Monkeypox/M24_01_07.jpg
#   inflating: dataset/Train/Monkeypox/M24_01_08.jpg
#   inflating: dataset/Train/Monkeypox/M24_01_09.jpg
#   inflating: dataset/Train/Monkeypox/M24_01_10.jpg
#   inflating: dataset/Train/Monkeypox/M24_01_11.jpg
#   inflating: dataset/Train/Monkeypox/M24_01_12.jpg
#   inflating: dataset/Train/Monkeypox/M24_01_13.jpg
#   inflating: dataset/Train/Monkeypox/M24_02_00.jpg
#   inflating: dataset/Train/Monkeypox/M24_02_01.jpg
#   inflating: dataset/Train/Monkeypox/M24_02_02.jpg
#   inflating: dataset/Train/Monkeypox/M24_02_03.jpg
#   inflating: dataset/Train/Monkeypox/M24_02_04.jpg
#   inflating: dataset/Train/Monkeypox/M24_02_05.jpg
#   inflating: dataset/Train/Monkeypox/M24_02_06.jpg
#   inflating: dataset/Train/Monkeypox/M24_02_07.jpg
#   inflating: dataset/Train/Monkeypox/M24_02_08.jpg
#   inflating: dataset/Train/Monkeypox/M24_02_09.jpg
#   inflating: dataset/Train/Monkeypox/M24_02_10.jpg
#   inflating: dataset/Train/Monkeypox/M24_02_11.jpg
#   inflating: dataset/Train/Monkeypox/M24_02_12.jpg
#   inflating: dataset/Train/Monkeypox/M24_02_13.jpg
#   inflating: dataset/Train/Monkeypox/M25_01_00.jpg
#   inflating: dataset/Train/Monkeypox/M25_01_01.jpg
#   inflating: dataset/Train/Monkeypox/M25_01_02.jpg
#   inflating: dataset/Train/Monkeypox/M25_01_03.jpg
#   inflating: dataset/Train/Monkeypox/M25_01_04.jpg
#   inflating: dataset/Train/Monkeypox/M25_01_05.jpg
#   inflating: dataset/Train/Monkeypox/M25_01_06.jpg
#   inflating: dataset/Train/Monkeypox/M25_01_07.jpg
#   inflating: dataset/Train/Monkeypox/M25_01_08.jpg
#   inflating: dataset/Train/Monkeypox/M25_01_09.jpg
#   inflating: dataset/Train/Monkeypox/M25_01_10.jpg
#   inflating: dataset/Train/Monkeypox/M25_01_11.jpg
#   inflating: dataset/Train/Monkeypox/M25_01_12.jpg
#   inflating: dataset/Train/Monkeypox/M25_01_13.jpg
#   inflating: dataset/Train/Monkeypox/M25_02_00.jpg
#   inflating: dataset/Train/Monkeypox/M25_02_01.jpg
#   inflating: dataset/Train/Monkeypox/M25_02_02.jpg
#   inflating: dataset/Train/Monkeypox/M25_02_03.jpg
#   inflating: dataset/Train/Monkeypox/M25_02_04.jpg
#   inflating: dataset/Train/Monkeypox/M25_02_05.jpg
#   inflating: dataset/Train/Monkeypox/M25_02_06.jpg
#   inflating: dataset/Train/Monkeypox/M25_02_07.jpg
#   inflating: dataset/Train/Monkeypox/M25_02_08.jpg
#   inflating: dataset/Train/Monkeypox/M25_02_09.jpg
#   inflating: dataset/Train/Monkeypox/M25_02_10.jpg
#   inflating: dataset/Train/Monkeypox/M25_02_11.jpg
#   inflating: dataset/Train/Monkeypox/M25_02_12.jpg
#   inflating: dataset/Train/Monkeypox/M25_02_13.jpg
#   inflating: dataset/Train/Monkeypox/M26_01_00.jpg
#   inflating: dataset/Train/Monkeypox/M26_01_01.jpg
#   inflating: dataset/Train/Monkeypox/M26_01_02.jpg
#   inflating: dataset/Train/Monkeypox/M26_01_03.jpg
#   inflating: dataset/Train/Monkeypox/M26_01_04.jpg
#   inflating: dataset/Train/Monkeypox/M26_01_05.jpg
#   inflating: dataset/Train/Monkeypox/M26_01_06.jpg
#   inflating: dataset/Train/Monkeypox/M26_01_07.jpg
#   inflating: dataset/Train/Monkeypox/M26_01_08.jpg
#   inflating: dataset/Train/Monkeypox/M26_01_09.jpg
#   inflating: dataset/Train/Monkeypox/M26_01_10.jpg
#   inflating: dataset/Train/Monkeypox/M26_01_11.jpg
#   inflating: dataset/Train/Monkeypox/M26_01_12.jpg
#   inflating: dataset/Train/Monkeypox/M26_01_13.jpg
#   inflating: dataset/Train/Monkeypox/M26_02_00.jpg
#   inflating: dataset/Train/Monkeypox/M26_02_01.jpg
#   inflating: dataset/Train/Monkeypox/M26_02_02.jpg
#   inflating: dataset/Train/Monkeypox/M26_02_03.jpg
#   inflating: dataset/Train/Monkeypox/M26_02_04.jpg
#   inflating: dataset/Train/Monkeypox/M26_02_05.jpg
#   inflating: dataset/Train/Monkeypox/M26_02_06.jpg
#   inflating: dataset/Train/Monkeypox/M26_02_07.jpg
#   inflating: dataset/Train/Monkeypox/M26_02_08.jpg
#   inflating: dataset/Train/Monkeypox/M26_02_09.jpg
#   inflating: dataset/Train/Monkeypox/M26_02_10.jpg
#   inflating: dataset/Train/Monkeypox/M26_02_11.jpg
#   inflating: dataset/Train/Monkeypox/M26_02_12.jpg
#   inflating: dataset/Train/Monkeypox/M26_02_13.jpg
#   inflating: dataset/Train/Monkeypox/M27_01_00.jpg
#   inflating: dataset/Train/Monkeypox/M27_01_01.jpg
#   inflating: dataset/Train/Monkeypox/M27_01_02.jpg
#   inflating: dataset/Train/Monkeypox/M27_01_03.jpg
#   inflating: dataset/Train/Monkeypox/M27_01_04.jpg
#   inflating: dataset/Train/Monkeypox/M27_01_05.jpg
#   inflating: dataset/Train/Monkeypox/M27_01_06.jpg
#   inflating: dataset/Train/Monkeypox/M27_01_07.jpg
#   inflating: dataset/Train/Monkeypox/M27_01_08.jpg
#   inflating: dataset/Train/Monkeypox/M27_01_09.jpg
#   inflating: dataset/Train/Monkeypox/M27_01_10.jpg
#   inflating: dataset/Train/Monkeypox/M27_01_11.jpg
#   inflating: dataset/Train/Monkeypox/M27_01_12.jpg
#   inflating: dataset/Train/Monkeypox/M27_01_13.jpg
#   inflating: dataset/Train/Monkeypox/M28_01_00.jpg
#   inflating: dataset/Train/Monkeypox/M28_01_01.jpg
#   inflating: dataset/Train/Monkeypox/M28_01_02.jpg
#   inflating: dataset/Train/Monkeypox/M28_01_03.jpg
#   inflating: dataset/Train/Monkeypox/M28_01_04.jpg
#   inflating: dataset/Train/Monkeypox/M28_01_05.jpg
#   inflating: dataset/Train/Monkeypox/M28_01_06.jpg
#   inflating: dataset/Train/Monkeypox/M28_01_07.jpg
#   inflating: dataset/Train/Monkeypox/M28_01_08.jpg
#   inflating: dataset/Train/Monkeypox/M28_01_09.jpg
#   inflating: dataset/Train/Monkeypox/M28_01_10.jpg
#   inflating: dataset/Train/Monkeypox/M28_01_11.jpg
#   inflating: dataset/Train/Monkeypox/M28_01_12.jpg
#   inflating: dataset/Train/Monkeypox/M28_01_13.jpg
#   inflating: dataset/Train/Monkeypox/M28_02_00.jpg
#   inflating: dataset/Train/Monkeypox/M28_02_01.jpg
#   inflating: dataset/Train/Monkeypox/M28_02_02.jpg
#   inflating: dataset/Train/Monkeypox/M28_02_03.jpg
#   inflating: dataset/Train/Monkeypox/M28_02_04.jpg
#   inflating: dataset/Train/Monkeypox/M28_02_05.jpg
#   inflating: dataset/Train/Monkeypox/M28_02_06.jpg
#   inflating: dataset/Train/Monkeypox/M28_02_07.jpg
#   inflating: dataset/Train/Monkeypox/M28_02_08.jpg
#   inflating: dataset/Train/Monkeypox/M28_02_09.jpg
#   inflating: dataset/Train/Monkeypox/M28_02_10.jpg
#   inflating: dataset/Train/Monkeypox/M28_02_11.jpg
#   inflating: dataset/Train/Monkeypox/M28_02_12.jpg
#   inflating: dataset/Train/Monkeypox/M28_02_13.jpg
#   inflating: dataset/Train/Monkeypox/M28_03_00.jpg
#   inflating: dataset/Train/Monkeypox/M28_03_01.jpg
#   inflating: dataset/Train/Monkeypox/M28_03_02.jpg
#   inflating: dataset/Train/Monkeypox/M28_03_03.jpg
#   inflating: dataset/Train/Monkeypox/M28_03_04.jpg
#   inflating: dataset/Train/Monkeypox/M28_03_05.jpg
#   inflating: dataset/Train/Monkeypox/M28_03_06.jpg
#   inflating: dataset/Train/Monkeypox/M28_03_07.jpg
#   inflating: dataset/Train/Monkeypox/M28_03_08.jpg
#   inflating: dataset/Train/Monkeypox/M28_03_09.jpg
#   inflating: dataset/Train/Monkeypox/M28_03_10.jpg
#   inflating: dataset/Train/Monkeypox/M28_03_11.jpg
#   inflating: dataset/Train/Monkeypox/M28_03_12.jpg
#   inflating: dataset/Train/Monkeypox/M28_03_13.jpg
#   inflating: dataset/Train/Monkeypox/M28_04_00.jpg
#   inflating: dataset/Train/Monkeypox/M28_04_01.jpg
#   inflating: dataset/Train/Monkeypox/M28_04_02.jpg
#   inflating: dataset/Train/Monkeypox/M28_04_03.jpg
#   inflating: dataset/Train/Monkeypox/M28_04_04.jpg
#   inflating: dataset/Train/Monkeypox/M28_04_05.jpg
#   inflating: dataset/Train/Monkeypox/M28_04_06.jpg
#   inflating: dataset/Train/Monkeypox/M28_04_07.jpg
#   inflating: dataset/Train/Monkeypox/M28_04_08.jpg
#   inflating: dataset/Train/Monkeypox/M28_04_09.jpg
#   inflating: dataset/Train/Monkeypox/M28_04_10.jpg
#   inflating: dataset/Train/Monkeypox/M28_04_11.jpg
#   inflating: dataset/Train/Monkeypox/M28_04_12.jpg
#   inflating: dataset/Train/Monkeypox/M28_04_13.jpg
#   inflating: dataset/Train/Monkeypox/M29_01_00.jpg
#   inflating: dataset/Train/Monkeypox/M29_01_01.jpg
#   inflating: dataset/Train/Monkeypox/M29_01_02.jpg
#   inflating: dataset/Train/Monkeypox/M29_01_03.jpg
#   inflating: dataset/Train/Monkeypox/M29_01_04.jpg
#   inflating: dataset/Train/Monkeypox/M29_01_05.jpg
#   inflating: dataset/Train/Monkeypox/M29_01_06.jpg
#   inflating: dataset/Train/Monkeypox/M29_01_07.jpg
#   inflating: dataset/Train/Monkeypox/M29_01_08.jpg
#   inflating: dataset/Train/Monkeypox/M29_01_09.jpg
#   inflating: dataset/Train/Monkeypox/M29_01_10.jpg
#   inflating: dataset/Train/Monkeypox/M29_01_11.jpg
#   inflating: dataset/Train/Monkeypox/M29_01_12.jpg
#   inflating: dataset/Train/Monkeypox/M29_01_13.jpg
#   inflating: dataset/Train/Monkeypox/M29_02_00.jpg
#   inflating: dataset/Train/Monkeypox/M29_02_01.jpg
#   inflating: dataset/Train/Monkeypox/M29_02_02.jpg
#   inflating: dataset/Train/Monkeypox/M29_02_03.jpg
#   inflating: dataset/Train/Monkeypox/M29_02_04.jpg
#   inflating: dataset/Train/Monkeypox/M29_02_05.jpg
#   inflating: dataset/Train/Monkeypox/M29_02_06.jpg
#   inflating: dataset/Train/Monkeypox/M29_02_07.jpg
#   inflating: dataset/Train/Monkeypox/M29_02_08.jpg
#   inflating: dataset/Train/Monkeypox/M29_02_09.jpg
#   inflating: dataset/Train/Monkeypox/M29_02_10.jpg
#   inflating: dataset/Train/Monkeypox/M29_02_11.jpg
#   inflating: dataset/Train/Monkeypox/M29_02_12.jpg
#   inflating: dataset/Train/Monkeypox/M29_02_13.jpg
#   inflating: dataset/Train/Monkeypox/M30_01_00.jpg
#   inflating: dataset/Train/Monkeypox/M30_01_01.jpg
#   inflating: dataset/Train/Monkeypox/M30_01_02.jpg
#   inflating: dataset/Train/Monkeypox/M30_01_03.jpg
#   inflating: dataset/Train/Monkeypox/M30_01_04.jpg
#   inflating: dataset/Train/Monkeypox/M30_01_05.jpg
#   inflating: dataset/Train/Monkeypox/M30_01_06.jpg
#   inflating: dataset/Train/Monkeypox/M30_01_07.jpg
#   inflating: dataset/Train/Monkeypox/M30_01_08.jpg
#   inflating: dataset/Train/Monkeypox/M30_01_09.jpg
#   inflating: dataset/Train/Monkeypox/M30_01_10.jpg
#   inflating: dataset/Train/Monkeypox/M30_01_11.jpg
#   inflating: dataset/Train/Monkeypox/M30_01_12.jpg
#   inflating: dataset/Train/Monkeypox/M30_01_13.jpg
#   inflating: dataset/Train/Monkeypox/M30_02_00.jpg
#   inflating: dataset/Train/Monkeypox/M30_02_01.jpg
#   inflating: dataset/Train/Monkeypox/M30_02_02.jpg
#   inflating: dataset/Train/Monkeypox/M30_02_03.jpg
#   inflating: dataset/Train/Monkeypox/M30_02_04.jpg
#   inflating: dataset/Train/Monkeypox/M30_02_05.jpg
#   inflating: dataset/Train/Monkeypox/M30_02_06.jpg
#   inflating: dataset/Train/Monkeypox/M30_02_07.jpg
#   inflating: dataset/Train/Monkeypox/M30_02_08.jpg
#   inflating: dataset/Train/Monkeypox/M30_02_09.jpg
#   inflating: dataset/Train/Monkeypox/M30_02_10.jpg
#   inflating: dataset/Train/Monkeypox/M30_02_11.jpg
#   inflating: dataset/Train/Monkeypox/M30_02_12.jpg
#   inflating: dataset/Train/Monkeypox/M30_02_13.jpg
#   inflating: dataset/Train/Monkeypox/M31_01_00.jpg
#   inflating: dataset/Train/Monkeypox/M31_01_01.jpg
#   inflating: dataset/Train/Monkeypox/M31_01_02.jpg
#   inflating: dataset/Train/Monkeypox/M31_01_03.jpg
#   inflating: dataset/Train/Monkeypox/M31_01_04.jpg
#   inflating: dataset/Train/Monkeypox/M31_01_05.jpg
#   inflating: dataset/Train/Monkeypox/M31_01_06.jpg
#   inflating: dataset/Train/Monkeypox/M31_01_07.jpg
#   inflating: dataset/Train/Monkeypox/M31_01_08.jpg
#   inflating: dataset/Train/Monkeypox/M31_01_09.jpg
#   inflating: dataset/Train/Monkeypox/M31_01_10.jpg
#   inflating: dataset/Train/Monkeypox/M31_01_11.jpg
#   inflating: dataset/Train/Monkeypox/M31_01_12.jpg
#   inflating: dataset/Train/Monkeypox/M31_01_13.jpg
#   inflating: dataset/Train/Monkeypox/M31_02_00.jpg
#   inflating: dataset/Train/Monkeypox/M31_02_01.jpg
#   inflating: dataset/Train/Monkeypox/M31_02_02.jpg
#   inflating: dataset/Train/Monkeypox/M31_02_03.jpg
#   inflating: dataset/Train/Monkeypox/M31_02_04.jpg
#   inflating: dataset/Train/Monkeypox/M31_02_05.jpg
#   inflating: dataset/Train/Monkeypox/M31_02_06.jpg
#   inflating: dataset/Train/Monkeypox/M31_02_07.jpg
#   inflating: dataset/Train/Monkeypox/M31_02_08.jpg
#   inflating: dataset/Train/Monkeypox/M31_02_09.jpg
#   inflating: dataset/Train/Monkeypox/M31_02_10.jpg
#   inflating: dataset/Train/Monkeypox/M31_02_11.jpg
#   inflating: dataset/Train/Monkeypox/M31_02_12.jpg
#   inflating: dataset/Train/Monkeypox/M31_02_13.jpg
#   inflating: dataset/Train/Monkeypox/M32_01_00.jpg
#   inflating: dataset/Train/Monkeypox/M32_01_01.jpg
#   inflating: dataset/Train/Monkeypox/M32_01_02.jpg
#   inflating: dataset/Train/Monkeypox/M32_01_03.jpg
#   inflating: dataset/Train/Monkeypox/M32_01_04.jpg
#   inflating: dataset/Train/Monkeypox/M32_01_05.jpg
#   inflating: dataset/Train/Monkeypox/M32_01_06.jpg
#   inflating: dataset/Train/Monkeypox/M32_01_07.jpg
#   inflating: dataset/Train/Monkeypox/M32_01_08.jpg
#   inflating: dataset/Train/Monkeypox/M32_01_09.jpg
#   inflating: dataset/Train/Monkeypox/M32_01_10.jpg
#   inflating: dataset/Train/Monkeypox/M32_01_11.jpg
#   inflating: dataset/Train/Monkeypox/M32_01_12.jpg
#   inflating: dataset/Train/Monkeypox/M32_01_13.jpg
#   inflating: dataset/Train/Monkeypox/M32_02_00.jpg
#   inflating: dataset/Train/Monkeypox/M32_02_01.jpg
#   inflating: dataset/Train/Monkeypox/M32_02_02.jpg
#   inflating: dataset/Train/Monkeypox/M32_02_03.jpg
#   inflating: dataset/Train/Monkeypox/M32_02_04.jpg
#   inflating: dataset/Train/Monkeypox/M32_02_05.jpg
#   inflating: dataset/Train/Monkeypox/M32_02_06.jpg
#   inflating: dataset/Train/Monkeypox/M32_02_07.jpg
#   inflating: dataset/Train/Monkeypox/M32_02_08.jpg
#   inflating: dataset/Train/Monkeypox/M32_02_09.jpg
#   inflating: dataset/Train/Monkeypox/M32_02_10.jpg
#   inflating: dataset/Train/Monkeypox/M32_02_11.jpg
#   inflating: dataset/Train/Monkeypox/M32_02_12.jpg
#   inflating: dataset/Train/Monkeypox/M32_02_13.jpg
#   inflating: dataset/Train/Monkeypox/M32_03_00.jpg
#   inflating: dataset/Train/Monkeypox/M32_03_01.jpg
#   inflating: dataset/Train/Monkeypox/M32_03_02.jpg
#   inflating: dataset/Train/Monkeypox/M32_03_03.jpg
#   inflating: dataset/Train/Monkeypox/M32_03_04.jpg
#   inflating: dataset/Train/Monkeypox/M32_03_05.jpg
#   inflating: dataset/Train/Monkeypox/M32_03_06.jpg
#   inflating: dataset/Train/Monkeypox/M32_03_07.jpg
#   inflating: dataset/Train/Monkeypox/M32_03_08.jpg
#   inflating: dataset/Train/Monkeypox/M32_03_09.jpg
#   inflating: dataset/Train/Monkeypox/M32_03_10.jpg
#   inflating: dataset/Train/Monkeypox/M32_03_11.jpg
#   inflating: dataset/Train/Monkeypox/M32_03_12.jpg
#   inflating: dataset/Train/Monkeypox/M32_03_13.jpg
#   inflating: dataset/Train/Monkeypox/M32_04_00.jpg
#   inflating: dataset/Train/Monkeypox/M32_04_01.jpg
#   inflating: dataset/Train/Monkeypox/M32_04_02.jpg
#   inflating: dataset/Train/Monkeypox/M32_04_03.jpg
#   inflating: dataset/Train/Monkeypox/M32_04_04.jpg
#   inflating: dataset/Train/Monkeypox/M32_04_05.jpg
#   inflating: dataset/Train/Monkeypox/M32_04_06.jpg
#   inflating: dataset/Train/Monkeypox/M32_04_07.jpg
#   inflating: dataset/Train/Monkeypox/M32_04_08.jpg
#   inflating: dataset/Train/Monkeypox/M32_04_09.jpg
#   inflating: dataset/Train/Monkeypox/M32_04_10.jpg
#   inflating: dataset/Train/Monkeypox/M32_04_11.jpg
#   inflating: dataset/Train/Monkeypox/M32_04_12.jpg
#   inflating: dataset/Train/Monkeypox/M32_04_13.jpg
#   inflating: dataset/Train/Monkeypox/M33_01_00.jpg
#   inflating: dataset/Train/Monkeypox/M33_01_01.jpg
#   inflating: dataset/Train/Monkeypox/M33_01_02.jpg
#   inflating: dataset/Train/Monkeypox/M33_01_03.jpg
#   inflating: dataset/Train/Monkeypox/M33_01_04.jpg
#   inflating: dataset/Train/Monkeypox/M33_01_05.jpg
#   inflating: dataset/Train/Monkeypox/M33_01_06.jpg
#   inflating: dataset/Train/Monkeypox/M33_01_07.jpg
#   inflating: dataset/Train/Monkeypox/M33_01_08.jpg
#   inflating: dataset/Train/Monkeypox/M33_01_09.jpg
#   inflating: dataset/Train/Monkeypox/M33_01_10.jpg
#   inflating: dataset/Train/Monkeypox/M33_01_11.jpg
#   inflating: dataset/Train/Monkeypox/M33_01_12.jpg
#   inflating: dataset/Train/Monkeypox/M33_01_13.jpg
#   inflating: dataset/Train/Monkeypox/M33_02_00.jpg
#   inflating: dataset/Train/Monkeypox/M33_02_01.jpg
#   inflating: dataset/Train/Monkeypox/M33_02_02.jpg
#   inflating: dataset/Train/Monkeypox/M33_02_03.jpg
#   inflating: dataset/Train/Monkeypox/M33_02_04.jpg
#   inflating: dataset/Train/Monkeypox/M33_02_05.jpg
#   inflating: dataset/Train/Monkeypox/M33_02_06.jpg
#   inflating: dataset/Train/Monkeypox/M33_02_07.jpg
#   inflating: dataset/Train/Monkeypox/M33_02_08.jpg
#   inflating: dataset/Train/Monkeypox/M33_02_09.jpg
#   inflating: dataset/Train/Monkeypox/M33_02_10.jpg
#   inflating: dataset/Train/Monkeypox/M33_02_11.jpg
#   inflating: dataset/Train/Monkeypox/M33_02_12.jpg
#   inflating: dataset/Train/Monkeypox/M33_02_13.jpg
#   inflating: dataset/Train/Monkeypox/M34_01_00.jpg
#   inflating: dataset/Train/Monkeypox/M34_01_01.jpg
#   inflating: dataset/Train/Monkeypox/M34_01_02.jpg
#   inflating: dataset/Train/Monkeypox/M34_01_03.jpg
#   inflating: dataset/Train/Monkeypox/M34_01_04.jpg
#   inflating: dataset/Train/Monkeypox/M34_01_05.jpg
#   inflating: dataset/Train/Monkeypox/M34_01_06.jpg
#   inflating: dataset/Train/Monkeypox/M34_01_07.jpg
#   inflating: dataset/Train/Monkeypox/M34_01_08.jpg
#   inflating: dataset/Train/Monkeypox/M34_01_09.jpg
#   inflating: dataset/Train/Monkeypox/M34_01_10.jpg
#   inflating: dataset/Train/Monkeypox/M34_01_11.jpg
#   inflating: dataset/Train/Monkeypox/M34_01_12.jpg
#   inflating: dataset/Train/Monkeypox/M34_01_13.jpg
#   inflating: dataset/Train/Monkeypox/M34_02_00.jpg
#   inflating: dataset/Train/Monkeypox/M34_02_01.jpg
#   inflating: dataset/Train/Monkeypox/M34_02_02.jpg
#   inflating: dataset/Train/Monkeypox/M34_02_03.jpg
#   inflating: dataset/Train/Monkeypox/M34_02_04.jpg
#   inflating: dataset/Train/Monkeypox/M34_02_05.jpg
#   inflating: dataset/Train/Monkeypox/M34_02_06.jpg
#   inflating: dataset/Train/Monkeypox/M34_02_07.jpg
#   inflating: dataset/Train/Monkeypox/M34_02_08.jpg
#   inflating: dataset/Train/Monkeypox/M34_02_09.jpg
#   inflating: dataset/Train/Monkeypox/M34_02_10.jpg
#   inflating: dataset/Train/Monkeypox/M34_02_11.jpg
#   inflating: dataset/Train/Monkeypox/M34_02_12.jpg
#   inflating: dataset/Train/Monkeypox/M34_02_13.jpg
#   inflating: dataset/Train/Monkeypox/M34_03_00.jpg
#   inflating: dataset/Train/Monkeypox/M34_03_01.jpg
#   inflating: dataset/Train/Monkeypox/M34_03_02.jpg
#   inflating: dataset/Train/Monkeypox/M34_03_03.jpg
#   inflating: dataset/Train/Monkeypox/M34_03_04.jpg
#   inflating: dataset/Train/Monkeypox/M34_03_05.jpg
#   inflating: dataset/Train/Monkeypox/M34_03_06.jpg
#   inflating: dataset/Train/Monkeypox/M34_03_07.jpg
#   inflating: dataset/Train/Monkeypox/M34_03_08.jpg
#   inflating: dataset/Train/Monkeypox/M34_03_09.jpg
#   inflating: dataset/Train/Monkeypox/M34_03_10.jpg
#   inflating: dataset/Train/Monkeypox/M34_03_11.jpg
#   inflating: dataset/Train/Monkeypox/M34_03_12.jpg
#   inflating: dataset/Train/Monkeypox/M34_03_13.jpg
#   inflating: dataset/Train/Monkeypox/M34_04_00.jpg
#   inflating: dataset/Train/Monkeypox/M34_04_01.jpg
#   inflating: dataset/Train/Monkeypox/M34_04_02.jpg
#   inflating: dataset/Train/Monkeypox/M34_04_03.jpg
#   inflating: dataset/Train/Monkeypox/M34_04_04.jpg
#   inflating: dataset/Train/Monkeypox/M34_04_05.jpg
#   inflating: dataset/Train/Monkeypox/M34_04_06.jpg
#   inflating: dataset/Train/Monkeypox/M34_04_07.jpg
#   inflating: dataset/Train/Monkeypox/M34_04_08.jpg
#   inflating: dataset/Train/Monkeypox/M34_04_09.jpg
#   inflating: dataset/Train/Monkeypox/M34_04_10.jpg
#   inflating: dataset/Train/Monkeypox/M34_04_11.jpg
#   inflating: dataset/Train/Monkeypox/M34_04_12.jpg
#   inflating: dataset/Train/Monkeypox/M34_04_13.jpg
#   inflating: dataset/Train/Monkeypox/M35_01_00.jpg
#   inflating: dataset/Train/Monkeypox/M35_01_01.jpg
#   inflating: dataset/Train/Monkeypox/M35_01_02.jpg
#   inflating: dataset/Train/Monkeypox/M35_01_03.jpg
#   inflating: dataset/Train/Monkeypox/M35_01_04.jpg
#   inflating: dataset/Train/Monkeypox/M35_01_05.jpg
#   inflating: dataset/Train/Monkeypox/M35_01_06.jpg
#   inflating: dataset/Train/Monkeypox/M35_01_07.jpg
#   inflating: dataset/Train/Monkeypox/M35_01_08.jpg
#   inflating: dataset/Train/Monkeypox/M35_01_09.jpg
#   inflating: dataset/Train/Monkeypox/M35_01_10.jpg
#   inflating: dataset/Train/Monkeypox/M35_01_11.jpg
#   inflating: dataset/Train/Monkeypox/M35_01_12.jpg
#   inflating: dataset/Train/Monkeypox/M35_01_13.jpg
#   inflating: dataset/Train/Monkeypox/M35_02_00.jpg
#   inflating: dataset/Train/Monkeypox/M35_02_01.jpg
#   inflating: dataset/Train/Monkeypox/M35_02_02.jpg
#   inflating: dataset/Train/Monkeypox/M35_02_03.jpg
#   inflating: dataset/Train/Monkeypox/M35_02_04.jpg
#   inflating: dataset/Train/Monkeypox/M35_02_05.jpg
#   inflating: dataset/Train/Monkeypox/M35_02_06.jpg
#   inflating: dataset/Train/Monkeypox/M35_02_07.jpg
#   inflating: dataset/Train/Monkeypox/M35_02_08.jpg
#   inflating: dataset/Train/Monkeypox/M35_02_09.jpg
#   inflating: dataset/Train/Monkeypox/M35_02_10.jpg
#   inflating: dataset/Train/Monkeypox/M35_02_11.jpg
#   inflating: dataset/Train/Monkeypox/M35_02_12.jpg
#   inflating: dataset/Train/Monkeypox/M35_02_13.jpg
#   inflating: dataset/Train/Monkeypox/M36_01_00.jpg
#   inflating: dataset/Train/Monkeypox/M36_01_01.jpg
#   inflating: dataset/Train/Monkeypox/M36_01_02.jpg
#   inflating: dataset/Train/Monkeypox/M36_01_03.jpg
#   inflating: dataset/Train/Monkeypox/M36_01_04.jpg
#   inflating: dataset/Train/Monkeypox/M36_01_05.jpg
#   inflating: dataset/Train/Monkeypox/M36_01_06.jpg
#   inflating: dataset/Train/Monkeypox/M36_01_07.jpg
#   inflating: dataset/Train/Monkeypox/M36_01_08.jpg
#   inflating: dataset/Train/Monkeypox/M36_01_09.jpg
#   inflating: dataset/Train/Monkeypox/M36_01_10.jpg
#   inflating: dataset/Train/Monkeypox/M36_01_11.jpg
#   inflating: dataset/Train/Monkeypox/M36_01_12.jpg
#   inflating: dataset/Train/Monkeypox/M36_01_13.jpg
#   inflating: dataset/Train/Monkeypox/M37_01_00.jpg
#   inflating: dataset/Train/Monkeypox/M37_01_01.jpg
#   inflating: dataset/Train/Monkeypox/M37_01_02.jpg
#   inflating: dataset/Train/Monkeypox/M37_01_03.jpg
#   inflating: dataset/Train/Monkeypox/M37_01_04.jpg
#   inflating: dataset/Train/Monkeypox/M37_01_05.jpg
#   inflating: dataset/Train/Monkeypox/M37_01_06.jpg
# ...
#   inflating: dataset/Train/Others/NM81_01_11.jpg
#   inflating: dataset/Train/Others/NM81_01_12.jpg
#   inflating: dataset/Train/Others/NM81_01_13.jpg
#   inflating: dataset/Train/Others/NM82_01_00.jpg
#   inflating: dataset/Train/Others/NM82_01_01.jpg
#   inflating: dataset/Train/Others/NM82_01_02.jpg
#   inflating: dataset/Train/Others/NM82_01_03.jpg
#   inflating: dataset/Train/Others/NM82_01_04.jpg
#   inflating: dataset/Train/Others/NM82_01_05.jpg
#   inflating: dataset/Train/Others/NM82_01_06.jpg
#   inflating: dataset/Train/Others/NM82_01_07.jpg
#   inflating: dataset/Train/Others/NM82_01_08.jpg
#   inflating: dataset/Train/Others/NM82_01_09.jpg
#   inflating: dataset/Train/Others/NM82_01_10.jpg
#   inflating: dataset/Train/Others/NM82_01_11.jpg
#   inflating: dataset/Train/Others/NM82_01_12.jpg
#   inflating: dataset/Train/Others/NM82_01_13.jpg
#   inflating: dataset/Train/Others/NM83_01_00.jpg
#   inflating: dataset/Train/Others/NM83_01_01.jpg
#   inflating: dataset/Train/Others/NM83_01_02.jpg
#   inflating: dataset/Train/Others/NM83_01_03.jpg
#   inflating: dataset/Train/Others/NM83_01_04.jpg
#   inflating: dataset/Train/Others/NM83_01_05.jpg
#   inflating: dataset/Train/Others/NM83_01_06.jpg
#   inflating: dataset/Train/Others/NM83_01_07.jpg
#   inflating: dataset/Train/Others/NM83_01_08.jpg
#   inflating: dataset/Train/Others/NM83_01_09.jpg
#   inflating: dataset/Train/Others/NM83_01_10.jpg
#   inflating: dataset/Train/Others/NM83_01_11.jpg
#   inflating: dataset/Train/Others/NM83_01_12.jpg
#   inflating: dataset/Train/Others/NM83_01_13.jpg
#   inflating: dataset/Train/Others/NM84_01_00.jpg
#   inflating: dataset/Train/Others/NM84_01_01.jpg
#   inflating: dataset/Train/Others/NM84_01_02.jpg
#   inflating: dataset/Train/Others/NM84_01_03.jpg
#   inflating: dataset/Train/Others/NM84_01_04.jpg
#   inflating: dataset/Train/Others/NM84_01_05.jpg
#   inflating: dataset/Train/Others/NM84_01_06.jpg
#   inflating: dataset/Train/Others/NM84_01_07.jpg
#   inflating: dataset/Train/Others/NM84_01_08.jpg
#   inflating: dataset/Train/Others/NM84_01_09.jpg
#   inflating: dataset/Train/Others/NM84_01_10.jpg
#   inflating: dataset/Train/Others/NM84_01_11.jpg
#   inflating: dataset/Train/Others/NM84_01_12.jpg
#   inflating: dataset/Train/Others/NM84_01_13.jpg
#   inflating: dataset/Train/Others/NM86_01_00.jpg
#   inflating: dataset/Train/Others/NM86_01_01.jpg
#   inflating: dataset/Train/Others/NM86_01_02.jpg
#   inflating: dataset/Train/Others/NM86_01_03.jpg
#   inflating: dataset/Train/Others/NM86_01_04.jpg
#   inflating: dataset/Train/Others/NM86_01_05.jpg
#   inflating: dataset/Train/Others/NM86_01_06.jpg
#   inflating: dataset/Train/Others/NM86_01_07.jpg
#   inflating: dataset/Train/Others/NM86_01_08.jpg
#   inflating: dataset/Train/Others/NM86_01_09.jpg
#   inflating: dataset/Train/Others/NM86_01_10.jpg
#   inflating: dataset/Train/Others/NM86_01_11.jpg
#   inflating: dataset/Train/Others/NM86_01_12.jpg
#   inflating: dataset/Train/Others/NM86_01_13.jpg
#   inflating: dataset/Train/Others/NM87_01_00.jpg
#   inflating: dataset/Train/Others/NM87_01_01.jpg
#   inflating: dataset/Train/Others/NM87_01_02.jpg
#   inflating: dataset/Train/Others/NM87_01_03.jpg
#   inflating: dataset/Train/Others/NM87_01_04.jpg
#   inflating: dataset/Train/Others/NM87_01_05.jpg
#   inflating: dataset/Train/Others/NM87_01_06.jpg
#   inflating: dataset/Train/Others/NM87_01_07.jpg
#   inflating: dataset/Train/Others/NM87_01_08.jpg
#   inflating: dataset/Train/Others/NM87_01_09.jpg
#   inflating: dataset/Train/Others/NM87_01_10.jpg
#   inflating: dataset/Train/Others/NM87_01_11.jpg
#   inflating: dataset/Train/Others/NM87_01_12.jpg
#   inflating: dataset/Train/Others/NM87_01_13.jpg
#   inflating: dataset/Train/Others/NM88_01_00.jpg
#   inflating: dataset/Train/Others/NM88_01_01.jpg
#   inflating: dataset/Train/Others/NM88_01_02.jpg
#   inflating: dataset/Train/Others/NM88_01_03.jpg
#   inflating: dataset/Train/Others/NM88_01_04.jpg
#   inflating: dataset/Train/Others/NM88_01_05.jpg
#   inflating: dataset/Train/Others/NM88_01_06.jpg
#   inflating: dataset/Train/Others/NM88_01_07.jpg
#   inflating: dataset/Train/Others/NM88_01_08.jpg
#   inflating: dataset/Train/Others/NM88_01_09.jpg
#   inflating: dataset/Train/Others/NM88_01_10.jpg
#   inflating: dataset/Train/Others/NM88_01_11.jpg
#   inflating: dataset/Train/Others/NM88_01_12.jpg
#   inflating: dataset/Train/Others/NM88_01_13.jpg
#   inflating: dataset/Train/Others/NM89_01_00.jpg
#   inflating: dataset/Train/Others/NM89_01_01.jpg
#   inflating: dataset/Train/Others/NM89_01_02.jpg
#   inflating: dataset/Train/Others/NM89_01_03.jpg
#   inflating: dataset/Train/Others/NM89_01_04.jpg
#   inflating: dataset/Train/Others/NM89_01_05.jpg
#   inflating: dataset/Train/Others/NM89_01_06.jpg
#   inflating: dataset/Train/Others/NM89_01_07.jpg
#   inflating: dataset/Train/Others/NM89_01_08.jpg
#   inflating: dataset/Train/Others/NM89_01_09.jpg
#   inflating: dataset/Train/Others/NM89_01_10.jpg
#   inflating: dataset/Train/Others/NM89_01_11.jpg
#   inflating: dataset/Train/Others/NM89_01_12.jpg
#   inflating: dataset/Train/Others/NM89_01_13.jpg
#   inflating: dataset/Train/Others/NM90_01_00.jpg
#   inflating: dataset/Train/Others/NM90_01_01.jpg
#   inflating: dataset/Train/Others/NM90_01_02.jpg
#   inflating: dataset/Train/Others/NM90_01_03.jpg
#   inflating: dataset/Train/Others/NM90_01_04.jpg
#   inflating: dataset/Train/Others/NM90_01_05.jpg
#   inflating: dataset/Train/Others/NM90_01_06.jpg
#   inflating: dataset/Train/Others/NM90_01_07.jpg
#   inflating: dataset/Train/Others/NM90_01_08.jpg
#   inflating: dataset/Train/Others/NM90_01_09.jpg
#   inflating: dataset/Train/Others/NM90_01_10.jpg
#   inflating: dataset/Train/Others/NM90_01_11.jpg
#   inflating: dataset/Train/Others/NM90_01_12.jpg
#   inflating: dataset/Train/Others/NM90_01_13.jpg
#   inflating: dataset/Train/Others/NM91_01_00.jpg
#   inflating: dataset/Train/Others/NM91_01_01.jpg
#   inflating: dataset/Train/Others/NM91_01_02.jpg
#   inflating: dataset/Train/Others/NM91_01_03.jpg
#   inflating: dataset/Train/Others/NM91_01_04.jpg
#   inflating: dataset/Train/Others/NM91_01_05.jpg
#   inflating: dataset/Train/Others/NM91_01_06.jpg
#   inflating: dataset/Train/Others/NM91_01_07.jpg
#   inflating: dataset/Train/Others/NM91_01_08.jpg
#   inflating: dataset/Train/Others/NM91_01_09.jpg
#   inflating: dataset/Train/Others/NM91_01_10.jpg
#   inflating: dataset/Train/Others/NM91_01_11.jpg
#   inflating: dataset/Train/Others/NM91_01_12.jpg
#   inflating: dataset/Train/Others/NM91_01_13.jpg
#   inflating: dataset/Train/Others/NM91_02_00.jpg
#   inflating: dataset/Train/Others/NM91_02_01.jpg
#   inflating: dataset/Train/Others/NM91_02_02.jpg
#   inflating: dataset/Train/Others/NM91_02_03.jpg
#   inflating: dataset/Train/Others/NM91_02_04.jpg
#   inflating: dataset/Train/Others/NM91_02_05.jpg
#   inflating: dataset/Train/Others/NM91_02_06.jpg
#   inflating: dataset/Train/Others/NM91_02_07.jpg
#   inflating: dataset/Train/Others/NM91_02_08.jpg
#   inflating: dataset/Train/Others/NM91_02_09.jpg
#   inflating: dataset/Train/Others/NM91_02_10.jpg
#   inflating: dataset/Train/Others/NM91_02_11.jpg
#   inflating: dataset/Train/Others/NM91_02_12.jpg
#   inflating: dataset/Train/Others/NM91_02_13.jpg
#   inflating: dataset/Train/Others/NM93_01_00.jpg
#   inflating: dataset/Train/Others/NM93_01_01.jpg
#   inflating: dataset/Train/Others/NM93_01_02.jpg
#   inflating: dataset/Train/Others/NM93_01_03.jpg
#   inflating: dataset/Train/Others/NM93_01_04.jpg
#   inflating: dataset/Train/Others/NM93_01_05.jpg
#   inflating: dataset/Train/Others/NM93_01_06.jpg
#   inflating: dataset/Train/Others/NM93_01_07.jpg
#   inflating: dataset/Train/Others/NM93_01_08.jpg
#   inflating: dataset/Train/Others/NM93_01_09.jpg
#   inflating: dataset/Train/Others/NM93_01_10.jpg
#   inflating: dataset/Train/Others/NM93_01_11.jpg
#   inflating: dataset/Train/Others/NM93_01_12.jpg
#   inflating: dataset/Train/Others/NM93_01_13.jpg
#   inflating: dataset/Train/Others/NM94_01_00.jpg
#   inflating: dataset/Train/Others/NM94_01_01.jpg
#   inflating: dataset/Train/Others/NM94_01_02.jpg
#   inflating: dataset/Train/Others/NM94_01_03.jpg
#   inflating: dataset/Train/Others/NM94_01_04.jpg
#   inflating: dataset/Train/Others/NM94_01_05.jpg
#   inflating: dataset/Train/Others/NM94_01_06.jpg
#   inflating: dataset/Train/Others/NM94_01_07.jpg
#   inflating: dataset/Train/Others/NM94_01_08.jpg
#   inflating: dataset/Train/Others/NM94_01_09.jpg
#   inflating: dataset/Train/Others/NM94_01_10.jpg
#   inflating: dataset/Train/Others/NM94_01_11.jpg
#   inflating: dataset/Train/Others/NM94_01_12.jpg
#   inflating: dataset/Train/Others/NM94_01_13.jpg
#   inflating: dataset/Train/Others/NM95_01_00.jpg
#   inflating: dataset/Train/Others/NM95_01_01.jpg
#   inflating: dataset/Train/Others/NM95_01_02.jpg
#   inflating: dataset/Train/Others/NM95_01_03.jpg
#   inflating: dataset/Train/Others/NM95_01_04.jpg
#   inflating: dataset/Train/Others/NM95_01_05.jpg
#   inflating: dataset/Train/Others/NM95_01_06.jpg
#   inflating: dataset/Train/Others/NM95_01_07.jpg
#   inflating: dataset/Train/Others/NM95_01_08.jpg
#   inflating: dataset/Train/Others/NM95_01_09.jpg
#   inflating: dataset/Train/Others/NM95_01_10.jpg
#   inflating: dataset/Train/Others/NM95_01_11.jpg
#   inflating: dataset/Train/Others/NM95_01_12.jpg
#   inflating: dataset/Train/Others/NM95_01_13.jpg
#   inflating: dataset/Train/Others/NM96_01_00.jpg
#   inflating: dataset/Train/Others/NM96_01_01.jpg
#   inflating: dataset/Train/Others/NM96_01_02.jpg
#   inflating: dataset/Train/Others/NM96_01_03.jpg
#   inflating: dataset/Train/Others/NM96_01_04.jpg
#   inflating: dataset/Train/Others/NM96_01_05.jpg
#   inflating: dataset/Train/Others/NM96_01_06.jpg
#   inflating: dataset/Train/Others/NM96_01_07.jpg
#   inflating: dataset/Train/Others/NM96_01_08.jpg
#   inflating: dataset/Train/Others/NM96_01_09.jpg
#   inflating: dataset/Train/Others/NM96_01_10.jpg
#   inflating: dataset/Train/Others/NM96_01_11.jpg
#   inflating: dataset/Train/Others/NM96_01_12.jpg
#   inflating: dataset/Train/Others/NM96_01_13.jpg
#   inflating: dataset/Train/Others/NM97_01_00.jpg
#   inflating: dataset/Train/Others/NM97_01_01.jpg
#   inflating: dataset/Train/Others/NM97_01_02.jpg
#   inflating: dataset/Train/Others/NM97_01_03.jpg
#   inflating: dataset/Train/Others/NM97_01_04.jpg
#   inflating: dataset/Train/Others/NM97_01_05.jpg
#   inflating: dataset/Train/Others/NM97_01_06.jpg
#   inflating: dataset/Train/Others/NM97_01_07.jpg
#   inflating: dataset/Train/Others/NM97_01_08.jpg
#   inflating: dataset/Train/Others/NM97_01_09.jpg
#   inflating: dataset/Train/Others/NM97_01_10.jpg
#   inflating: dataset/Train/Others/NM97_01_11.jpg
#   inflating: dataset/Train/Others/NM97_01_12.jpg
#   inflating: dataset/Train/Others/NM97_01_13.jpg
#   inflating: dataset/Train/Others/NM98_01_00.jpg
#   inflating: dataset/Train/Others/NM98_01_01.jpg
#   inflating: dataset/Train/Others/NM98_01_02.jpg
#   inflating: dataset/Train/Others/NM98_01_03.jpg
#   inflating: dataset/Train/Others/NM98_01_04.jpg
#   inflating: dataset/Train/Others/NM98_01_05.jpg
#   inflating: dataset/Train/Others/NM98_01_06.jpg
#   inflating: dataset/Train/Others/NM98_01_07.jpg
#   inflating: dataset/Train/Others/NM98_01_08.jpg
#   inflating: dataset/Train/Others/NM98_01_09.jpg
#   inflating: dataset/Train/Others/NM98_01_10.jpg
#   inflating: dataset/Train/Others/NM98_01_11.jpg
#   inflating: dataset/Train/Others/NM98_01_12.jpg
#   inflating: dataset/Train/Others/NM98_01_13.jpg
#   inflating: dataset/Train/Others/NM98_02_00.jpg
#   inflating: dataset/Train/Others/NM98_02_01.jpg
#   inflating: dataset/Train/Others/NM98_02_02.jpg
#   inflating: dataset/Train/Others/NM98_02_03.jpg
#   inflating: dataset/Train/Others/NM98_02_04.jpg
#   inflating: dataset/Train/Others/NM98_02_05.jpg
#   inflating: dataset/Train/Others/NM98_02_06.jpg
#   inflating: dataset/Train/Others/NM98_02_07.jpg
#   inflating: dataset/Train/Others/NM98_02_08.jpg
#   inflating: dataset/Train/Others/NM98_02_09.jpg
#   inflating: dataset/Train/Others/NM98_02_10.jpg
#   inflating: dataset/Train/Others/NM98_02_11.jpg
#   inflating: dataset/Train/Others/NM98_02_12.jpg
#   inflating: dataset/Train/Others/NM98_02_13.jpg
#   inflating: dataset/Train/Others/NM99_01_00.jpg
#   inflating: dataset/Train/Others/NM99_01_01.jpg
#   inflating: dataset/Train/Others/NM99_01_02.jpg
#   inflating: dataset/Train/Others/NM99_01_03.jpg
#   inflating: dataset/Train/Others/NM99_01_04.jpg
#   inflating: dataset/Train/Others/NM99_01_05.jpg
#   inflating: dataset/Train/Others/NM99_01_06.jpg
#   inflating: dataset/Train/Others/NM99_01_07.jpg
#   inflating: dataset/Train/Others/NM99_01_08.jpg
#   inflating: dataset/Train/Others/NM99_01_09.jpg
#   inflating: dataset/Train/Others/NM99_01_10.jpg
#   inflating: dataset/Train/Others/NM99_01_11.jpg
#   inflating: dataset/Train/Others/NM99_01_12.jpg
#   inflating: dataset/Train/Others/NM99_01_13.jpg
#   inflating: dataset/Train/Others/NM99_02_00.jpg
#   inflating: dataset/Train/Others/NM99_02_01.jpg
#   inflating: dataset/Train/Others/NM99_02_02.jpg
#   inflating: dataset/Train/Others/NM99_02_03.jpg
#   inflating: dataset/Train/Others/NM99_02_04.jpg
#   inflating: dataset/Train/Others/NM99_02_05.jpg
#   inflating: dataset/Train/Others/NM99_02_06.jpg
#   inflating: dataset/Train/Others/NM99_02_07.jpg
#   inflating: dataset/Train/Others/NM99_02_08.jpg
#   inflating: dataset/Train/Others/NM99_02_09.jpg
#   inflating: dataset/Train/Others/NM99_02_10.jpg
#   inflating: dataset/Train/Others/NM99_02_11.jpg
#   inflating: dataset/Train/Others/NM99_02_12.jpg
#   inflating: dataset/Train/Others/NM99_02_13.jpg
#    creating: dataset/Test/
#    creating: dataset/Test/Monkeypox/
#   inflating: dataset/Test/Monkeypox/M04_01.jpg
#   inflating: dataset/Test/Monkeypox/M19_01.jpg
#   inflating: dataset/Test/Monkeypox/M19_02.jpg
#   inflating: dataset/Test/Monkeypox/M23_01.jpg
#   inflating: dataset/Test/Monkeypox/M38_01.jpg
#   inflating: dataset/Test/Monkeypox/M38_02.jpg
#   inflating: dataset/Test/Monkeypox/M39_01.jpg
#   inflating: dataset/Test/Monkeypox/M39_02.jpg
#   inflating: dataset/Test/Monkeypox/M40_01.jpg
#   inflating: dataset/Test/Monkeypox/M40_02.jpg
#   inflating: dataset/Test/Monkeypox/M40_03.jpg
#   inflating: dataset/Test/Monkeypox/M43_01.jpg
#   inflating: dataset/Test/Monkeypox/M43_02.jpg
#   inflating: dataset/Test/Monkeypox/M43_03.jpg
#   inflating: dataset/Test/Monkeypox/M45_01.jpg
#   inflating: dataset/Test/Monkeypox/M48_01.jpg
#   inflating: dataset/Test/Monkeypox/M48_02.jpg
#   inflating: dataset/Test/Monkeypox/M48_03.jpg
#   inflating: dataset/Test/Monkeypox/M51_01.jpg
#   inflating: dataset/Test/Monkeypox/M51_02.jpg
#    creating: dataset/Test/Others/
#   inflating: dataset/Test/Others/NM02_01.jpg
#   inflating: dataset/Test/Others/NM101_01.jpg
#   inflating: dataset/Test/Others/NM101_02.jpg
#   inflating: dataset/Test/Others/NM10_01.jpg
#   inflating: dataset/Test/Others/NM12_01.jpg
#   inflating: dataset/Test/Others/NM14_01.jpg
#   inflating: dataset/Test/Others/NM17_01.jpg
#   inflating: dataset/Test/Others/NM19_01.jpg
#   inflating: dataset/Test/Others/NM23_01.jpg
#   inflating: dataset/Test/Others/NM31_01.jpg
#   inflating: dataset/Test/Others/NM35_01.jpg
#   inflating: dataset/Test/Others/NM36_01.jpg
#   inflating: dataset/Test/Others/NM41_01.jpg
#   inflating: dataset/Test/Others/NM41_02.jpg
#   inflating: dataset/Test/Others/NM52_01.jpg
#   inflating: dataset/Test/Others/NM54_01.jpg
#   inflating: dataset/Test/Others/NM54_02.jpg
#   inflating: dataset/Test/Others/NM58_01.jpg
#   inflating: dataset/Test/Others/NM58_02.jpg
#   inflating: dataset/Test/Others/NM67_01.jpg
#   inflating: dataset/Test/Others/NM71_01.jpg
#   inflating: dataset/Test/Others/NM72_01.jpg
#   inflating: dataset/Test/Others/NM79_01.jpg
#   inflating: dataset/Test/Others/NM80_01.jpg
#   inflating: dataset/Test/Others/NM85_01.jpg

# %%
# Setup directory paths to train and test images
train_dir = '/content/dataset/Train'
test_dir = '/content/dataset/Test'

# %% [markdown]
# ## And now we've got transforms ready, we can turn our images into DataLoaders using the create_dataloaders()

# %%
NUM_WORKERS = os.cpu_count()

def create_dataloaders(
    train_dir: str,
    test_dir: str,
    transform: transforms.Compose,
    batch_size: int,
    num_workers: int=NUM_WORKERS
):

  # Use ImageFolder to create dataset(s)
  train_data = datasets.ImageFolder(train_dir, transform=transform)
  test_data = datasets.ImageFolder(test_dir, transform=transform)

  # Get class names
  class_names = train_data.classes

  # Turn images into data loaders
  train_dataloader = DataLoader(
      train_data,
      batch_size=batch_size,
      shuffle=True,
      num_workers=num_workers,
      pin_memory=True,
  )
  test_dataloader = DataLoader(
      test_data,
      batch_size=batch_size,
      shuffle=False,
      num_workers=num_workers,
      pin_memory=True,
  )

  return train_dataloader, test_dataloader, class_names

# %%
# Setup dataloaders
train_dataloader_pretrained, test_dataloader_pretrained, class_names = create_dataloaders(train_dir=train_dir,
                                                                                                     test_dir=test_dir,
                                                                                                     transform=pretrained_mobilevit_transforms,
                                                                                                     batch_size=16)

# %% [markdown]
# # Setting up the training and testing functions and start the training

# %%
from typing import Tuple
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score

# Define the training and testing steps with required metrics
def test_step(model: torch.nn.Module,
              dataloader: torch.utils.data.DataLoader,
              loss_fn: torch.nn.Module,
              device: torch.device) -> Tuple[float, float, float, float, float, float]:
    model.eval()
    test_loss, total_correct, total_samples = 0, 0, 0
    all_preds, all_labels = [], []

    with torch.inference_mode():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            test_pred_logits = model(X)

            loss = loss_fn(test_pred_logits, y)
            test_loss += loss.item()

            test_pred_labels = test_pred_logits.argmax(dim=1)
            total_correct += (test_pred_labels == y).sum().item()
            total_samples += y.size(0)

            # Store the predictions and true labels for evaluation
            all_preds.extend(test_pred_labels.cpu().numpy())
            all_labels.extend(y.cpu().numpy())

    # Calculate all required metrics
    test_precision = precision_score(all_labels, all_preds, average='weighted')
    test_recall = recall_score(all_labels, all_preds, average='weighted')
    test_f1 = f1_score(all_labels, all_preds, average='weighted')
    test_auc = roc_auc_score(all_labels, all_preds, average='weighted') if len(set(all_labels)) > 2 else roc_auc_score(all_labels, all_preds)


    test_loss = test_loss / len(dataloader)
    test_acc = total_correct / total_samples

    return test_loss, test_acc, test_precision, test_recall, test_f1, test_auc


def train_step(model: torch.nn.Module,
               dataloader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer,
               device: torch.device) -> Tuple[float, float, float, float, float, float]:
    model.train()
    train_loss, total_correct, total_samples = 0, 0, 0
    all_preds, all_labels = [], []

    for X, y in dataloader:
        X, y = X.to(device), y.to(device)
        optimizer.zero_grad()

        y_pred = model(X)
        loss = loss_fn(y_pred, y)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        total_correct += (y_pred.argmax(dim=1) == y).sum().item()
        total_samples += y.size(0)

        # Store the predictions and true labels for evaluation
        all_preds.extend(y_pred.argmax(dim=1).cpu().numpy())
        all_labels.extend(y.cpu().numpy())

    # Calculate all required metrics
    train_precision = precision_score(all_labels, all_preds, average='weighted')
    train_recall = recall_score(all_labels, all_preds, average='weighted')
    train_f1 = f1_score(all_labels, all_preds, average='weighted')
    train_auc = roc_auc_score(all_labels, all_preds, average='weighted') if len(set(all_labels)) > 2 else roc_auc_score(all_labels, all_preds)


    train_loss = train_loss / len(dataloader)
    train_acc = total_correct / total_samples

    return train_loss, train_acc, train_precision, train_recall, train_f1, train_auc

from typing import Tuple
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score
import torch
# Define the train function that runs training and evaluation for multiple epochs
def train(model: torch.nn.Module,
          train_dataloader: torch.utils.data.DataLoader,
          test_dataloader: torch.utils.data.DataLoader,
          optimizer: torch.optim.Optimizer,
          loss_fn: torch.nn.Module,
          epochs: int,
          device: torch.device,
          patience: int = 5) -> dict:
    results = {
        "train_loss": [],
        "train_acc": [],
        "train_precision": [],
        "train_recall": [],
        "train_f1": [],
        "train_auc": [],
        "test_loss": [],
        "test_acc": [],
        "test_precision": [],
        "test_recall": [],
        "test_f1": [],
        "test_auc": []
    }

    model.to(device)
    best_loss = float('inf')
    patience_counter = 0

    for epoch in range(epochs):
        # Training step
        train_loss, train_acc, train_precision, train_recall, train_f1, train_auc = train_step(
            model=model,
            dataloader=train_dataloader,
            loss_fn=loss_fn,
            optimizer=optimizer,
            device=device
        )

        # Testing step
        test_loss, test_acc, test_precision, test_recall, test_f1, test_auc = test_step(
            model=model,
            dataloader=test_dataloader,
            loss_fn=loss_fn,
            device=device
        )

        # Print the results for the current epoch
        print(
            f"Epoch: {epoch+1} | "
            f"train_loss: {train_loss:.4f} | "
            f"train_acc: {train_acc:.4f} | "
            f"train_precision: {train_precision:.4f} | "
            f"train_recall: {train_recall:.4f} | "
            f"train_f1: {train_f1:.4f} | "
            f"train_auc: {train_auc:.4f} | "
            f"test_loss: {test_loss:.4f} | "
            f"test_acc: {test_acc:.4f} | "
            f"test_precision: {test_precision:.4f} | "
            f"test_recall: {test_recall:.4f} | "
            f"test_f1: {test_f1:.4f} | "
            f"test_auc: {test_auc:.4f}"
        )

        # Save the results for plotting later
        results["train_loss"].append(train_loss)
        results["train_acc"].append(train_acc)
        results["train_precision"].append(train_precision)
        results["train_recall"].append(train_recall)
        results["train_f1"].append(train_f1)
        results["train_auc"].append(train_auc)
        results["test_loss"].append(test_loss)
        results["test_acc"].append(test_acc)
        results["test_precision"].append(test_precision)
        results["test_recall"].append(test_recall)
        results["test_f1"].append(test_f1)
        results["test_auc"].append(test_auc)

        # Early stopping check
        if test_loss < best_loss:
            best_loss = test_loss
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print(f"Early stopping triggered at epoch {epoch+1}.")
                break

    return results

# Create optimizer and loss function
optimizer = torch.optim.Adam(params=pretrained_mobilevit.parameters(),
                             lr=1e-4,
                             weight_decay=1e-4)
loss_fn = torch.nn.CrossEntropyLoss()

# Train the classifier head of the pretrained  feature extractor model
set_seeds()

import time

# Measure training time
start_time = time.time()

# Train and test the model, and collect results (including precision, recall, F1, AUC, accuracy)
pretrained_mobilevit_results = train(
    model=pretrained_mobilevit,
    train_dataloader=train_dataloader_pretrained,
    test_dataloader=test_dataloader_pretrained,
    optimizer=optimizer,
    loss_fn=loss_fn,
    epochs=5,
    device=device,
    patience=3 # Stop if no improvement
)

# End timer
end_time = time.time()
total_training_time = end_time - start_time
print(f"\nTotal Training Time: {total_training_time:.2f} seconds")
print(f"Average Training Time per Epoch: {total_training_time/5:.2f} seconds")
# Out:
# Epoch: 1 | train_loss: 0.6241 | train_acc: 0.6909 | train_precision: 0.7269 | train_recall: 0.6909 | train_f1: 0.6648 | train_auc: 0.6637 | test_loss: 0.4413 | test_acc: 0.8667 | test_precision: 0.8709 | test_recall: 0.8667 | test_f1: 0.8671 | test_auc: 0.8700
# Epoch: 2 | train_loss: 0.4927 | train_acc: 0.7697 | train_precision: 0.7715 | train_recall: 0.7697 | train_f1: 0.7669 | train_auc: 0.7601 | test_loss: 0.2938 | test_acc: 0.9111 | test_precision: 0.9152 | test_recall: 0.9111 | test_f1: 0.9114 | test_auc: 0.9150
# Epoch: 3 | train_loss: 0.4164 | train_acc: 0.8146 | train_precision: 0.8164 | train_recall: 0.8146 | train_f1: 0.8129 | train_auc: 0.8068 | test_loss: 0.2256 | test_acc: 0.9556 | test_precision: 0.9556 | test_recall: 0.9556 | test_f1: 0.9556 | test_auc: 0.9550
# Epoch: 4 | train_loss: 0.3637 | train_acc: 0.8501 | train_precision: 0.8503 | train_recall: 0.8501 | train_f1: 0.8496 | train_auc: 0.8456 | test_loss: 0.2120 | test_acc: 0.9333 | test_precision: 0.9345 | test_recall: 0.9333 | test_f1: 0.9335 | test_auc: 0.9350
# Epoch: 5 | train_loss: 0.3279 | train_acc: 0.8540 | train_precision: 0.8539 | train_recall: 0.8540 | train_f1: 0.8537 | train_auc: 0.8505 | test_loss: 0.1967 | test_acc: 0.9778 | test_precision: 0.9786 | test_recall: 0.9778 | test_f1: 0.9777 | test_auc: 0.9750
#
# Total Training Time: 58.88 seconds
# Average Training Time per Epoch: 11.78 seconds

# %% [markdown]
# #Here is the function to calculate the inference time

# %%
def predict_with_timing(model, image_path, transform, class_names, device):
    model.eval()

    # Load and preprocess image
    image = Image.open(image_path).convert("RGB")
    input_tensor = transform(image).unsqueeze(0).to(device)

    # Warm-up pass (CUDA needs it for more accurate timing)
    with torch.inference_mode():
        _ = model(input_tensor)

    # Measure inference time
    start_time = time.time()
    with torch.inference_mode():
        outputs = model(input_tensor)
    end_time = time.time()

    # Process prediction
    probs = torch.softmax(outputs, dim=1).cpu().numpy()[0]
    pred_class = class_names[probs.argmax()]
    inference_time = (end_time - start_time) * 1000  # in milliseconds

    print(f"Predicted class: {pred_class}")
    print(f"\nClass probabilities: {dict(zip(class_names, probs.round(3)))}")
    print(f"\nInference time: {inference_time:.2f} ms")

    return pred_class, probs, inference_time

# %%
image_path = "/content/dataset/Test/Monkeypox/M40_03.jpg"  #Test the inference time on a random image
predict_with_timing(model, image_path, pretrained_mobilevit_transforms, class_names, device)
# Out:
# Predicted class: Monkeypox
#
# Class probabilities: {'Monkeypox': np.float32(0.984), 'Others': np.float32(0.016)}
#
# Inference time: 8.60 ms
# ('Monkeypox',
#  array([0.98449105, 0.01550891], dtype=float32),
#  8.597135543823242)

# %% [markdown]
# # Here we plot our evaluation matrices for the test and train data

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc
import numpy as np
def get_predictions_and_labels(model, dataloader, device):
    model.eval()
    all_preds, all_labels, all_probs = [], [], []

    with torch.inference_mode():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            logits = model(X)
            probs = torch.softmax(logits, dim=1)[:, 1]  # probability of class 1
            preds = torch.argmax(logits, dim=1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(y.cpu().numpy())
            all_probs.extend(probs.cpu().numpy())

    return np.array(all_preds), np.array(all_labels), np.array(all_probs)

# Get preds, labels, and probs for ROC
y_pred, y_true, y_probs = get_predictions_and_labels(model, test_dataloader_pretrained, device)

# %%
import matplotlib.pyplot as plt
# Define the function to plot the curves for all metrics
def plot_all_metrics(results, y_true, y_pred, y_probs, class_names):
    epochs = range(len(results["train_loss"]))

    plt.figure(figsize=(18, 12))


    # Loss
    plt.subplot(3, 3, 1)
    plt.plot(epochs, results["train_loss"], label="train_loss")
    plt.plot(epochs, results["test_loss"], label="test_loss")
    plt.title("Loss")
    plt.xlabel("Epochs")
    plt.legend()

    # Accuracy
    plt.subplot(3, 3, 2)
    plt.plot(epochs, results["train_acc"], label="train_acc")
    plt.plot(epochs, results["test_acc"], label="test_acc")
    plt.title("Accuracy")
    plt.xlabel("Epochs")
    plt.legend()

    # Recall
    plt.subplot(3, 3, 3)
    plt.plot(epochs, results["train_recall"], label="train_recall")
    plt.plot(epochs, results["test_recall"], label="test_recall")
    plt.title("Recall")
    plt.xlabel("Epochs")
    plt.legend()

    # Precision
    plt.subplot(3, 3, 4)
    plt.plot(epochs, results["train_precision"], label="train_precision")
    plt.plot(epochs, results["test_precision"], label="test_precision")
    plt.title("Precision")
    plt.xlabel("Epochs")
    plt.legend()

    # F1 Score
    plt.subplot(3, 3, 5)
    plt.plot(epochs, results["train_f1"], label="train_f1")
    plt.plot(epochs, results["test_f1"], label="test_f1")
    plt.title("F1 Score")
    plt.xlabel("Epochs")
    plt.legend()

    # AUC
    plt.subplot(3, 3, 6)
    plt.plot(epochs, results["train_auc"], label="train_auc")
    plt.plot(epochs, results["test_auc"], label="test_auc")
    plt.title("AUC")
    plt.xlabel("Epochs")
    plt.legend()

    # Confusion Matrix
    plt.subplot(3, 3, 7)
    cm = confusion_matrix(y_true, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
    disp.plot(cmap=plt.cm.Blues, ax=plt.gca(), colorbar=False)
    plt.title("Confusion Matrix")

    # ROC Curve
    plt.subplot(3, 3, 8)
    fpr, tpr, _ = roc_curve(y_true, y_probs)
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"ROC Curve (AUC = {roc_auc:.2f})")
    plt.plot([0, 1], [0, 1], "k--")
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("ROC Curve")
    plt.legend(loc="lower right")

    # Show the plots
    plt.tight_layout()
    plt.show()

# %%
plot_all_metrics(pretrained_mobilevit_results, y_true, y_pred, y_probs, class_names)

# %% [markdown]
# # Let's make Prediction:

# %%
def pred_and_plot_image(
    model: torch.nn.Module,
    class_names: List[str],
    image_path: str,
    image_size: Tuple[int, int] = (224, 224),
    transform: torchvision.transforms = None,
    device: torch.device = device,
):

    # Open image
    img = Image.open(image_path)

    # Create transformation for image (if one doesn't exist)
    if transform is not None:
        image_transform = transform
    else:
        image_transform = transforms.Compose(
            [
                transforms.Resize(image_size),
                transforms.ToTensor(),
                transforms.Normalize(
                    mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]
                ),
            ]
        )

    ### Predict on image ###

    # Make sure the model is on the target device
    model.to(device)

    # Turn on model evaluation mode and inference mode
    model.eval()
    with torch.inference_mode():
        # Transform and add an extra dimension to image (model requires samples in [batch_size, color_channels, height, width])
        transformed_image = image_transform(img).unsqueeze(dim=0)

        # Make a prediction on image with an extra dimension and send it to the target device
        target_image_pred = model(transformed_image.to(device))

    # Convert logits -> prediction probabilities (using torch.softmax() for multi-class classification)
    target_image_pred_probs = torch.softmax(target_image_pred, dim=1)

    # Convert prediction probabilities -> prediction labels
    target_image_pred_label = torch.argmax(target_image_pred_probs, dim=1)

    # Plot image with predicted label and probability
    plt.figure()
    plt.imshow(img)
    plt.title(
        f"Pred: {class_names[target_image_pred_label]} | Prob: {target_image_pred_probs.max():.3f}"
    )
    plt.axis(False)

# %%
# Setup custom image path
custom_image_path = "/content/dataset/Test/Others/NM41_01.jpg"
# Predict on custom image
pred_and_plot_image(model=pretrained_mobilevit,
                    image_path=custom_image_path,
                    class_names=class_names)

# %%
# Setup custom image path
custom_image_path = "/content/dataset/Test/Monkeypox/M51_02.jpg"

# Predict on custom image
pred_and_plot_image(model=pretrained_mobilevit,
                    image_path=custom_image_path,
                    class_names=class_names)
